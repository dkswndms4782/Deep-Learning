# %% [markdown]
# <a href="https://colab.research.google.com/github/dkswndms4782/Deep-Learning/blob/main/Blackjack_source_code_real.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # BlackJack : Monte-Carlo with Exploring Start
# ----
#
# ## 설명
# 블랙잭 게임에서의 최적 Policy를 찾는 프로그램입니다. 본 프로그램에서 정의된 블랙잭 룰은 다음과 같습니다.
#  - 하나의 카드 덱(조커를 제외한 52장의 카드)을 사용
#  - 카드의 합을 계산할 시 A = 1 or 11, J,Q,K = 10으로 계산
#  - 플레이어는 Hit 또는 Stick만을 할 수 있음
#  - 카드의 합이 21 이하일 경우, 딜러와 플레이어 중 숫자가 더 높은 쪽이 승리.
#  - 카드의 합이 21 초과한 딜러/플레이어는 패배
#  - 카드의 합이 같을 경우 무승부
#
# 본 프로그램에서는 최적 Policy를 찾기 위해 Monte-Carlo Control with Exploring Start[1] 알고리즘을 사용합니다. 최적 Policy를 찾기 위해, 본 프로그램은 다음과 같은 변수로 구성된 State로부터 탐색을 수행합니다.
#  - 플레이어 카드의 합 : 12 ~ 21 사이의 정수
#  - 딜러가 보여주는 카드의 숫자 : 1 ~ 10 사이의 정수
#  - 플레이어가 현재 사용 가능한 Ace의 유무 : True / False
#
# 위와 같이 구성된 State S에서 Action A를 선택했을 때의 기대 리턴(게임이 끝났을 때 얻을 것으로 기대되는 보상의 합)은 Q(S,A)입니다. 많은 에피소드를 경험할수혹 Agent는 Optimal Q(S,A)에 가까운 값을 학습하게 되며, 이로부터 최적 Policy를 찾을 수 있습니다.
#
# ----
#
# ## 0. Package
# 먼저 본 프로그램에서 사용할 Package를 Import합니다.

# %%
# %matplotlib inline
import random
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib import colors

# %% [markdown]
# ## 1. Class : Deck
# 카드 덱 한 벌에 해당하는 클래스를 선언합니다. 조커를 제외한 52장의 카드로 이루어져 있으며, 각 카드는 정수로 표기됩니다. <br>
# A = 11, J, Q, K = 10으로 표현되며, 나머지 카드는 해당 카드에 적힌 숫자만큼의 값을 갖습니다.
#
# ### 클래스 구성
# * Attributes
#    * card_deck : List, 52개의 정수로 이루어짐
# * Methods
#    * shuffle() : 카드 덱을 랜덤하게 섞음
#    * draw() : 카드 덱에서 한 장을 뽑아 리턴
#    * reset() : 카드 덱을 초기화함

# %%
class Deck(object):
    """
    Deck : Card deck, which can be shuffled, drawn, and reset.
    """

    def __init__(self):
        deck = [2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10, 11]
        self.card_deck = deck * 4
        self.shuffle()

    def shuffle(self):
        random.shuffle(self.card_deck)

    def draw(self):
        return self.card_deck.pop()

    def reset(self):
        deck = [2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10, 11]
        self.card_deck = deck * 4
        self.shuffle()

# %% [markdown]
# ## 2. Class : Dealer
# 다음으로 Dealer 클래스를 선언합니다.<br>
# Dealer 클래스는 강화학습에서의 Environment에 해당합니다. 플레이어의 Action을 받고, 그에 따른 다음 State와 Reward를 반환합니다.<br>
# 딜러는 시작할 때 두 장의 카드를 받습니다. 플레이어의 차례가 끝난 후, 플레이어의 카드 합이 21을 넘지 않는다면 딜러는 다음과 같이 행동합니다.
#  - 딜러 카드의 합이 17 미만일 때 : 카드 한 장을 추가로 뽑음 (Hit)
#  - 딜러 카드의 합이 17 이상일 때 : 플레이어의 카드 합과 비교하여 승패 결정 (Stick)
#
# ### 클래스 구성
# 딜러 클래스는 다음과 같이 구성됩니다
#  - Attributes
#      - hands : List, 딜러가 가지고 있는 카드들
#      - usable_ace : List, 딜러가 가지고 있는 A의 인덱스
#  - Methods
#      - hit(deck) : 카드 덱에서 카드 한 장을 뽑아 hands에 추가
#      - show() : 딜러가 가진 카드 중 랜덤한 한 장의 값을 리턴
#      - calculate_sum() : 딜러가 가진 카드의 합을 리턴. 카드 합이 21 이상일 때 사용 가능한 Ace가 있다면 사용함.
#      - action() : 딜러의 Action - 합이 17 미만이면 hit, 이상이면 stick
#      - observation(action, agent, deck) : 플레이어의 action을 받아 종료 여부와 reward 리턴
#      - calculate_rewards(agent, deck) : 플레이어와 딜러의 승패 계산 및 reward 리턴
#      - reset() : 딜러 클래스의 모든 attribute 초기화

# %%
class Dealer(object):
    """
    Dealer : 딜러 클래스
    딜러는 두 장의 카드를 받고, 카드의 합이 16 이하이면 Hit, 17이상이면 Stick 함.
    처음 두 장을 받았을 때 한 장의 카드를 랜덤하게 오픈함.
    """

    def __init__(self):
        """
        hand : 딜러가 가진 카드
        usable_ace : 딜러가 가진 카드 리스트 중 ace의 인덱스
        natural : 두 장의 카드로 21이 되면 True, 아니면 False
        """
        self.hands = list()
        self.usable_ace = list()

    def hit(self, deck: Deck):
        """
        딜러의 Hit. 새로운 카드가 Ace라면 사용 가능한 Ace 리스트에 추가함
        :param deck: Deck Object
        :return:
        """
        new_card = deck.draw()
        if new_card == 11:
            self.usable_ace.append(len(self.hands))
        self.hands.append(new_card)

    def show(self):
        """
        딜러가 가진 카드 중 하나를 랜덤하게 보여줌
        :return: 딜러의 카드 중 랜덤한 카드 숫자
        """
        card = random.choice(self.hands)
        if card == 11:
            card = 1
        return card

    def calculate_sum(self):
        """
        딜러가 가진 카드의 합을 구함
        21을 넘을 때 사용 가능한 Ace가 있으면 사용함
        :return: 딜러 카드의 합
        """
        sums = sum(self.hands)
        if sums > 21 and len(self.usable_ace) > 0:
            self.hands[self.usable_ace.pop()] = 1
            sums = sum(self.hands)
        return sums

    def action(self, deck: Deck):
        """
        딜러의 순서 때 딜러의 행동.
        숫자의 합이 16 이하일 때는 Hit, 17 이상이면 Stick
        :param deck:
        :return:
        """
        while True:
            sums = self.calculate_sum()
            if sums < 17:
                self.hit(deck)
            else:
                return sums

    def observation(self, action, agent, deck):
        """
        플레이어의 Action을 받아, 그에 맞는 Observation과 Reward를 반환
        :param action: agent 의 Action
        :param agent: agent 클래스
        :param deck: deck 클래스
        :return: 에피소드 종료 여부, reward
        """
        done = False
        reward = 0
        if action == True:  # Hit
            agent.hit(deck)
            if agent.calculate_sum() > 21:  #플레이어의 Hit으로 인해 카드 합이 21이 넘으면 즉시 종료
                done = True
                reward = -1
        else:  # Stick
            done = True
            reward = self.calcuate_reward(agent, deck)

        return done, reward

    def calcuate_reward(self, agent, deck):
        """
        플레이어가 Stick했을 때 딜러와의 카드 비교 수행
        :param agent:
        :param deck:
        :return: Reward
        """
        agent_sum = agent.calculate_sum()           # 플레이어의 카드 합 계산
        if agent_sum > 21:                          # 플레이어의 Bust (패)
            return -1

        dealer_sum = self.action(deck)              # 딜러의 카드 합 계산
        if dealer_sum > 21:                         # 딜러가 Bust (승)
            return 1
        if dealer_sum > agent_sum:                  # 딜러의 카드 합 > 플레이어 합 (패)
            return -1
        if dealer_sum < agent_sum:                  # 딜러의 카드 합 < 플레이어 합 (승)
            return 1
        return 0                                   # 딜러의 카드 합 == 플레이어의 합 (무)

    def reset(self):
        """
        딜러 초기화 (새로운 에피소드 시작을 위해)
        """
        self.hands = list()
        self.usable_ace = list()

# %% [markdown]
# ## 3. Class : Agent
# Agent 클래스는 플레이어에 해당하며, 최적 Policy를 학습하는 주체가 됩니다. Agent는 여러 에피소드들로부터 Q값(기대 Return)을 계산하고, 다음 에피소드 수행 시 해당 State에서 Q값이 높은 Action을 선택하는 Greedy Policy를 따릅니다.
#
# ### 클래스 구성
#
# Agent의 구성은 다음과 같습니다.
#
#  - Attributes
#      - hands : List, Agent가 가지고 있는 카드들
#      - usable_ace : List, Agent가 가지고 있는 A의 인덱스
#      - Q_table : Dictionary, 기대 Return값과 방문 횟수를 저장
#  - Methods
#      - hit(deck) : 카드 덱에서 카드 한 장을 뽑아 hands에 추가
#      - calculate_sum() : Agent가 가진 카드의 합을 리턴. 카드 합이 21 이상일 때 사용 가능한 Ace가 있다면 사용함.
#      - random_action() : 현재 State에 상관없이 랜덤하게 Action을 리턴
#      - policy(state) : 현재 State에서 가능한 Action 중, Q_table의 값이 큰 Action을 리턴
#      - update_qval(episode) : 에피소드로부터 평균 리턴을 계산하여 Q_table을 업데이트
#      - reset() : Agent 클래스의 모든 attribute 초기화

# %%
class Agent(object):
    def __init__(self):
        """
        hand : 플레이어의 카드
        usable_ace : 사용 가능한 ace 리스트
        Q_table : q(s,a) 값을 저장할 딕셔너리
        """
        self.hands = list()
        self.usable_ace = list()
        self.Q_table = dict()

    def hit(self, deck: Deck):
        """
        덱에서 새로운 카드를 뽑음
        :param deck: Deck for draw a card
        :return: None
        """
        new_card = deck.draw()
        if new_card == 11:
            self.usable_ace.append(len(self.hands))
        self.hands.append(new_card)

    def calculate_sum(self):
        """
        플레이어가 가진 카드의 합을 구함.
        21을 넘을 때 사용 가능한 ace가 있으면 사용함
        :return:
        """
        sums = sum(self.hands)
        if sums > 21 and len(self.usable_ace) > 0:
            self.hands[self.usable_ace.pop()] = 1
            sums = sum(self.hands)
        return sums

    def random_action(self):
        """
        랜덤하게 행동
        True = hit, False = stick
        :return:
        """
        return random.choice([True, False])

    def policy(self, state):
        """
        Agent의 policy 함수.
        e의 확률로 랜덤 행동을 하며, 그 외에는 현재 state에서 큰 q(s,a)값을 갖는 action을 선택함
        :param state: Agent에게 주어진 state
        :return: agent의 action을 반환 , True = hit and False = stick
        """
        # Q_table에서 현재 state-action에 대해 값이 존재하는지 검사함
        for action in (True, False):
            if (state, action) not in self.Q_table.keys():  # Q_table에 값이 없으면 0으로 초기화
                self.Q_table[(state, action)] = [0, 0]      # (mean return, visit count)
            else:
                continue

        # q값이 큰 action 선택
        if self.Q_table[(state, True)] > self.Q_table[(state, False)]:
            return True     # Hit
        elif self.Q_table[(state, True)] == self.Q_table[(state, False)]:   # q값이 같으면 무작위추출
            return self.random_action()
        else:
            return False    # Stick


    def reset(self):
        """
        Agent를 리셋함
        :return: None
        """
        self.hands = list()
        self.usable_ace = list()

    def update_qval(self, episode):
        """
        에피소드(한 번의 게임)으로부터 Q_table 을 업데이트함
        Q 테이블에 없는 state-action 쌍이 나오면 새로 생성
        Q 테이블에 state-action 쌍이 존재한다면 Incremental mean 적용하여 업데이트
        :param episode: Episode generated from environment
        :return: None
        """
        total_return = 0
        for state, action, reward in episode[::-1]:     # 에피소드의 뒤에서부터 (역순)
            total_return += reward                       # return Gt 계산
            if (state, action) not in self.Q_table.keys():  # state-action 쌍이 없다면
                self.Q_table[(state, action)] = [total_return, 1]   # 새롭게 엔트리 생성 (Gt, count)

            else:  #이미 존재하는 state-action 쌍이면 Incremental mean 적용
                prev_val = self.Q_table[(state, action)][0]         # 이전의 평균 return
                count = self.Q_table[(state, action)][1] + 1        # count 증가
                mean = prev_val + (total_return - prev_val) / count # 평균 계산 : Incremental Mean 적용
                self.Q_table[(state, action)] = [mean, count]  # 업데이트

# %% [markdown]
# ## 4. Class : MonteCarlo
# Monte-Carlo control with Exploring Start를 구현한 클래스입니다. 에피소드를 생성할 수 있고, 생성된 에피소드로부터 에이전트를 학습시킵니다.
# 에피소드 생성 시 Exploring Start를 위해 에피소드의 첫 번째 State에서는 무작위로 Action을 선택하며, 이후에는 에이전트의 Policy를 따라 Action을 선택합니다.
#
# ### 클래스 구성
# MonteCarlo 클래스는 다음과 같이 구성됩니다.
#  - Attribute
#      - 없음
#  - Methods
#      - generate_episode(dealer, agent, deck) : 딜러, 플레이어, 카드 덱을 이용해 한 번의 블랙잭 게임을 진행하고 에피소드를 반환합니다.
#      - train(dealer, agent, deck, it, verbose) : 지정된 이터레이션 수만큼의 에피소드로부터 플레이어를 학습시킵니다.

# %%
class MonteCarlo(object):
    def generate_episode(self, dealer: Dealer, agent: Agent, deck: Deck):
        """
        하나의 에피소드(게임)를 생성함
        :param dealer:
        :param agent:
        :param deck:
        :return:
        """
        
        # 카드 덱, 딜러, Agent를 초기화
        deck.reset()
        dealer.reset()
        agent.reset()
        agent.hit(deck)
        agent.hit(deck)
        dealer.hit(deck)
        dealer.hit(deck)

        done = False    # 에피소드의 종료 여부

        episode = list()    # 에피소드

        while not done:
            # 에피소드가 끝날 때까지 State, Action, Reward를 생성
            sums = agent.calculate_sum()
            if sums < 12:
                agent.hit(deck)
                continue

            state = (sums, bool(agent.usable_ace), dealer.show())

            ########   Exploring Start ~!!!!!!!!! : 
            if len(episode) == 0:       # 첫번째 State 일 때는 무작위 Action 선택
                action =agent.random_action()
            else:                       # 그 외에는 Q 테이블에서 큰 값을 갖는 Action 선택
                action = agent.policy(state)
            
            done, reward = dealer.observation(action, agent, deck)  # 에피소드 종료 여부, Reward 계산
            
            # 생성된 State, Action, Reward를 에피소드에 추가
            episode.append([state, action, reward])

        return episode

    def train(self, dealer: Dealer, agent: Agent, deck: Deck, it=10000, verbose=True):
        count = 0
        win = 0
        loss = 0
        draw = 0
        total_win = 0
        total_loss = 0
        total_draw = 0
        result = str()
        for i in range(it):
            count += 1
            episode = self.generate_episode(dealer, agent, deck)
            agent.update_qval(episode)

            if episode[-1][-1] == 1:
                win += 1
            elif episode[-1][-1] == 0:
                draw += 1
            else:
                loss += 1

            if count % 1000 == 0 and verbose == True:
                total_win += win
                total_loss += loss
                total_draw += draw

                print("========== Training : Episode ", count, " ===========")
                print("Recent 1000 games win rate :{:.3f}%".format(win / (win + loss) * 100))
                print(" -- 1000 Games WIN :", win, "DRAW :", draw, "LOSS :", loss)
                print("Total win rate : {:.3f}%".format(total_win / (total_win + total_loss) * 100))
                print(" -- TOTAL Games WIN :", total_win, "DRAW :", total_draw, "LOSS :", total_loss)

                win = 0
                loss = 0
                draw = 0

# %% [markdown]
# ## 5. Function : plot_q_val(agent, usable_ace)
# Q값을 시각화하기 위한 함수입니다.

# %%
def plot_q_val(agent: Agent, usable_ace=True):
    fig = plt.figure()
    ax = Axes3D(fig)

    hands = set()
    dealer_show = set()

    for state, action in sorted(agent.Q_table.keys()):
        hands.add(state[0])
        dealer_show.add(state[2])

    Z_list = list()

    l = list()

    for d in dealer_show:
        l = []
        for hand in hands:
            if ((hand, usable_ace, d), True) not in agent.Q_table.keys():
                agent.Q_table[((hand, usable_ace, d), True)] = [0, 0]
            if ((hand, usable_ace, d), False) not in agent.Q_table.keys():
                agent.Q_table[((hand, usable_ace, d), False)] = [0, 0]
            v_val = max([agent.Q_table[((hand, usable_ace, d), True)][0], agent.Q_table[((hand, usable_ace, d), False)][0]])
            l.append(v_val)
        Z_list.append(l)

    Y = np.array(list(hands))
    X = np.array(list(dealer_show))
    if usable_ace:
        X, Y = np.meshgrid(X, Y)
    else:
        X, Y = np.meshgrid(X, Y)

    Z = np.array(Z_list).T

    ax.plot_wireframe(X, Y, Z)
    plt.show()

# %% [markdown]
# ## 6. Function : plot_q_val(agent, usable_ace)
# 최적 Policy를 시각화하기 위한 함수입니다.

# %%
def plot_action(agent: Agent, usable_ace=True):
    hands = set()
    dealer_show = set()

    for state, action in sorted(agent.Q_table.keys()):
        hands.add(state[0])
        dealer_show.add(state[2])

    Z_list = list()

    l = list()

    action = False

    for d in dealer_show:
        l = []
        for hand in hands:
            if ((hand, usable_ace, d), True) not in agent.Q_table.keys():
                agent.Q_table[((hand, usable_ace, d), True)] = [0, 0]
            if ((hand, usable_ace, d), False) not in agent.Q_table.keys():
                agent.Q_table[((hand, usable_ace, d), False)] = [0, 0]
            l.append(0 if agent.Q_table[((hand, usable_ace, d), True)][0] > agent.Q_table[((hand, usable_ace, d), False)][0] else 1)
        Z_list.append(l)

    Y = np.array(list(hands))
    X = np.array(list(dealer_show))
    if usable_ace:
        X, Y = np.meshgrid(X, Y)
    else:
        X, Y = np.meshgrid(X, Y)
    Z = np.array(Z_list).T

    data = Z[::-1,:]
    data = np.append(data, [0 for _ in range(Z[0].shape[0])]).reshape(-1,Z[0].shape[0])
    
    cmap=cm.coolwarm
    plt.imshow(data, cmap=cmap, extent=[1,11,11,21])

    plt.show()
    return X, Y, Z

# %% [markdown]
# ## 7. 최적 Policy 학습

# %%
deck = Deck()
dealer = Dealer()
agent = Agent()
mc_es = MonteCarlo()

mc_es.train(dealer, agent, deck, it=1000000)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Recent 1000 games win rate :34.219%
#  -- 1000 Games WIN : 322 DRAW : 59 LOSS : 619
# Total win rate : 34.219%
#  -- TOTAL Games WIN : 322 DRAW : 59 LOSS : 619
# ========== Training : Episode  2000  ===========
# Recent 1000 games win rate :34.555%
#  -- 1000 Games WIN : 330 DRAW : 45 LOSS : 625
# Total win rate : 34.388%
#  -- TOTAL Games WIN : 652 DRAW : 104 LOSS : 1244
# ========== Training : Episode  3000  ===========
# Recent 1000 games win rate :37.353%
#  -- 1000 Games WIN : 350 DRAW : 63 LOSS : 587
# Total win rate : 35.369%
#  -- TOTAL Games WIN : 1002 DRAW : 167 LOSS : 1831
# ========== Training : Episode  4000  ===========
# Recent 1000 games win rate :34.787%
#  -- 1000 Games WIN : 327 DRAW : 60 LOSS : 613
# Total win rate : 35.224%
#  -- TOTAL Games WIN : 1329 DRAW : 227 LOSS : 2444
# ========== Training : Episode  5000  ===========
# Recent 1000 games win rate :35.722%
#  -- 1000 Games WIN : 334 DRAW : 65 LOSS : 601
# Total win rate : 35.323%
#  -- TOTAL Games WIN : 1663 DRAW : 292 LOSS : 3045
# ========== Training : Episode  6000  ===========
# Recent 1000 games win rate :34.783%
#  -- 1000 Games WIN : 328 DRAW : 57 LOSS : 615
# Total win rate : 35.233%
#  -- TOTAL Games WIN : 1991 DRAW : 349 LOSS : 3660
# ========== Training : Episode  7000  ===========
# Recent 1000 games win rate :35.560%
#  -- 1000 Games WIN : 330 DRAW : 72 LOSS : 598
# Total win rate : 35.279%
#  -- TOTAL Games WIN : 2321 DRAW : 421 LOSS : 4258
# ========== Training : Episode  8000  ===========
# Recent 1000 games win rate :37.419%
#  -- 1000 Games WIN : 348 DRAW : 70 LOSS : 582
# Total win rate : 35.544%
#  -- TOTAL Games WIN : 2669 DRAW : 491 LOSS : 4840
# ========== Training : Episode  9000  ===========
# Recent 1000 games win rate :37.989%
#  -- 1000 Games WIN : 359 DRAW : 55 LOSS : 586
# Total win rate : 35.817%
#  -- TOTAL Games WIN : 3028 DRAW : 546 LOSS : 5426
# ========== Training : Episode  10000  ===========
# Recent 1000 games win rate :34.219%
#  -- 1000 Games WIN : 322 DRAW : 59 LOSS : 619
# Total win rate : 35.657%
#  -- TOTAL Games WIN : 3350 DRAW : 605 LOSS : 6045
# ========== Training : Episode  11000  ===========
# Recent 1000 games win rate :33.900%
#  -- 1000 Games WIN : 319 DRAW : 59 LOSS : 622
# Total win rate : 35.497%
#  -- TOTAL Games WIN : 3669 DRAW : 664 LOSS : 6667
# ========== Training : Episode  12000  ===========
# Recent 1000 games win rate :32.593%
#  -- 1000 Games WIN : 308 DRAW : 55 LOSS : 637
# Total win rate : 35.254%
#  -- TOTAL Games WIN : 3977 DRAW : 719 LOSS : 7304
# ========== Training : Episode  13000  ===========
# Recent 1000 games win rate :35.843%
#  -- 1000 Games WIN : 338 DRAW : 57 LOSS : 605
# Total win rate : 35.299%
#  -- TOTAL Games WIN : 4315 DRAW : 776 LOSS : 7909
# ========== Training : Episode  14000  ===========
# Recent 1000 games win rate :35.446%
#  -- 1000 Games WIN : 330 DRAW : 69 LOSS : 601
# Total win rate : 35.310%
#  -- TOTAL Games WIN : 4645 DRAW : 845 LOSS : 8510
# ========== Training : Episode  15000  ===========
# Recent 1000 games win rate :37.605%
#  -- 1000 Games WIN : 358 DRAW : 48 LOSS : 594
# Total win rate : 35.465%
#  -- TOTAL Games WIN : 5003 DRAW : 893 LOSS : 9104
# ========== Training : Episode  16000  ===========
# Recent 1000 games win rate :35.525%
#  -- 1000 Games WIN : 335 DRAW : 57 LOSS : 608
# Total win rate : 35.468%
#  -- TOTAL Games WIN : 5338 DRAW : 950 LOSS : 9712
# ========== Training : Episode  17000  ===========
# Recent 1000 games win rate :34.861%
#  -- 1000 Games WIN : 327 DRAW : 62 LOSS : 611
# Total win rate : 35.433%
#  -- TOTAL Games WIN : 5665 DRAW : 1012 LOSS : 10323
# ========== Training : Episode  18000  ===========
# Recent 1000 games win rate :33.508%
#  -- 1000 Games WIN : 319 DRAW : 48 LOSS : 633
# Total win rate : 35.325%
#  -- TOTAL Games WIN : 5984 DRAW : 1060 LOSS : 10956
# ========== Training : Episode  19000  ===========
# Recent 1000 games win rate :36.730%
#  -- 1000 Games WIN : 346 DRAW : 58 LOSS : 596
# Total win rate : 35.399%
#  -- TOTAL Games WIN : 6330 DRAW : 1118 LOSS : 11552
# ========== Training : Episode  20000  ===========
# Recent 1000 games win rate :36.383%
#  -- 1000 Games WIN : 342 DRAW : 60 LOSS : 598
# Total win rate : 35.448%
#  -- TOTAL Games WIN : 6672 DRAW : 1178 LOSS : 12150
# ========== Training : Episode  21000  ===========
# Recent 1000 games win rate :37.580%
#  -- 1000 Games WIN : 351 DRAW : 66 LOSS : 583
# Total win rate : 35.549%
#  -- TOTAL Games WIN : 7023 DRAW : 1244 LOSS : 12733
# ========== Training : Episode  22000  ===========
# Recent 1000 games win rate :34.341%
#  -- 1000 Games WIN : 318 DRAW : 74 LOSS : 608
# Total win rate : 35.495%
#  -- TOTAL Games WIN : 7341 DRAW : 1318 LOSS : 13341
# ========== Training : Episode  23000  ===========
# Recent 1000 games win rate :36.205%
#  -- 1000 Games WIN : 332 DRAW : 83 LOSS : 585
# Total win rate : 35.525%
#  -- TOTAL Games WIN : 7673 DRAW : 1401 LOSS : 13926
# ========== Training : Episode  24000  ===========
# Recent 1000 games win rate :36.047%
#  -- 1000 Games WIN : 341 DRAW : 54 LOSS : 605
# Total win rate : 35.547%
#  -- TOTAL Games WIN : 8014 DRAW : 1455 LOSS : 14531
# ========== Training : Episode  25000  ===========
# Recent 1000 games win rate :32.303%
#  -- 1000 Games WIN : 303 DRAW : 62 LOSS : 635
# Total win rate : 35.417%
#  -- TOTAL Games WIN : 8317 DRAW : 1517 LOSS : 15166
# ========== Training : Episode  26000  ===========
# Recent 1000 games win rate :34.871%
#  -- 1000 Games WIN : 325 DRAW : 68 LOSS : 607
# Total win rate : 35.396%
#  -- TOTAL Games WIN : 8642 DRAW : 1585 LOSS : 15773
# ========== Training : Episode  27000  ===========
# Recent 1000 games win rate :35.654%
#  -- 1000 Games WIN : 338 DRAW : 52 LOSS : 610
# Total win rate : 35.406%
#  -- TOTAL Games WIN : 8980 DRAW : 1637 LOSS : 16383
# ========== Training : Episode  28000  ===========
# Recent 1000 games win rate :34.652%
#  -- 1000 Games WIN : 324 DRAW : 65 LOSS : 611
# Total win rate : 35.379%
#  -- TOTAL Games WIN : 9304 DRAW : 1702 LOSS : 16994
# ========== Training : Episode  29000  ===========
# Recent 1000 games win rate :35.144%
#  -- 1000 Games WIN : 330 DRAW : 61 LOSS : 609
# Total win rate : 35.371%
#  -- TOTAL Games WIN : 9634 DRAW : 1763 LOSS : 17603
# ========== Training : Episode  30000  ===========
# Recent 1000 games win rate :37.301%
#  -- 1000 Games WIN : 351 DRAW : 59 LOSS : 590
# Total win rate : 35.435%
#  -- TOTAL Games WIN : 9985 DRAW : 1822 LOSS : 18193
# ========== Training : Episode  31000  ===========
# Recent 1000 games win rate :36.653%
#  -- 1000 Games WIN : 346 DRAW : 56 LOSS : 598
# Total win rate : 35.475%
#  -- TOTAL Games WIN : 10331 DRAW : 1878 LOSS : 18791
# ========== Training : Episode  32000  ===========
# Recent 1000 games win rate :33.725%
#  -- 1000 Games WIN : 316 DRAW : 63 LOSS : 621
# Total win rate : 35.420%
#  -- TOTAL Games WIN : 10647 DRAW : 1941 LOSS : 19412
# ========== Training : Episode  33000  ===========
# Recent 1000 games win rate :35.646%
#  -- 1000 Games WIN : 334 DRAW : 63 LOSS : 603
# Total win rate : 35.427%
#  -- TOTAL Games WIN : 10981 DRAW : 2004 LOSS : 20015
# ========== Training : Episode  34000  ===========
# Recent 1000 games win rate :33.369%
#  -- 1000 Games WIN : 314 DRAW : 59 LOSS : 627
# Total win rate : 35.367%
#  -- TOTAL Games WIN : 11295 DRAW : 2063 LOSS : 20642
# ========== Training : Episode  35000  ===========
# Recent 1000 games win rate :37.204%
#  -- 1000 Games WIN : 346 DRAW : 70 LOSS : 584
# Total win rate : 35.419%
#  -- TOTAL Games WIN : 11641 DRAW : 2133 LOSS : 21226
# ========== Training : Episode  36000  ===========
# Recent 1000 games win rate :33.298%
#  -- 1000 Games WIN : 317 DRAW : 48 LOSS : 635
# Total win rate : 35.359%
#  -- TOTAL Games WIN : 11958 DRAW : 2181 LOSS : 21861
# ========== Training : Episode  37000  ===========
# Recent 1000 games win rate :35.954%
#  -- 1000 Games WIN : 343 DRAW : 46 LOSS : 611
# Total win rate : 35.375%
#  -- TOTAL Games WIN : 12301 DRAW : 2227 LOSS : 22472
# ========== Training : Episode  38000  ===========
# Recent 1000 games win rate :33.581%
#  -- 1000 Games WIN : 316 DRAW : 59 LOSS : 625
# Total win rate : 35.328%
#  -- TOTAL Games WIN : 12617 DRAW : 2286 LOSS : 23097
# ========== Training : Episode  39000  ===========
# Recent 1000 games win rate :36.134%
#  -- 1000 Games WIN : 344 DRAW : 48 LOSS : 608
# Total win rate : 35.349%
#  -- TOTAL Games WIN : 12961 DRAW : 2334 LOSS : 23705
# ========== Training : Episode  40000  ===========
# Recent 1000 games win rate :34.457%
#  -- 1000 Games WIN : 327 DRAW : 51 LOSS : 622
# Total win rate : 35.326%
#  -- TOTAL Games WIN : 13288 DRAW : 2385 LOSS : 24327
# ========== Training : Episode  41000  ===========
# Recent 1000 games win rate :33.051%
#  -- 1000 Games WIN : 312 DRAW : 56 LOSS : 632
# Total win rate : 35.271%
#  -- TOTAL Games WIN : 13600 DRAW : 2441 LOSS : 24959
# ========== Training : Episode  42000  ===========
# Recent 1000 games win rate :38.235%
#  -- 1000 Games WIN : 364 DRAW : 48 LOSS : 588
# Total win rate : 35.342%
#  -- TOTAL Games WIN : 13964 DRAW : 2489 LOSS : 25547
# ========== Training : Episode  43000  ===========
# Recent 1000 games win rate :34.358%
#  -- 1000 Games WIN : 324 DRAW : 57 LOSS : 619
# Total win rate : 35.319%
#  -- TOTAL Games WIN : 14288 DRAW : 2546 LOSS : 26166
# ========== Training : Episode  44000  ===========
# Recent 1000 games win rate :33.692%
#  -- 1000 Games WIN : 313 DRAW : 71 LOSS : 616
# Total win rate : 35.283%
#  -- TOTAL Games WIN : 14601 DRAW : 2617 LOSS : 26782
# ========== Training : Episode  45000  ===========
# Recent 1000 games win rate :37.057%
#  -- 1000 Games WIN : 345 DRAW : 69 LOSS : 586
# Total win rate : 35.322%
#  -- TOTAL Games WIN : 14946 DRAW : 2686 LOSS : 27368
# ========== Training : Episode  46000  ===========
# Recent 1000 games win rate :33.475%
#  -- 1000 Games WIN : 314 DRAW : 62 LOSS : 624
# Total win rate : 35.282%
#  -- TOTAL Games WIN : 15260 DRAW : 2748 LOSS : 27992
# ========== Training : Episode  47000  ===========
# Recent 1000 games win rate :36.200%
#  -- 1000 Games WIN : 341 DRAW : 58 LOSS : 601
# Total win rate : 35.301%
#  -- TOTAL Games WIN : 15601 DRAW : 2806 LOSS : 28593
# ========== Training : Episode  48000  ===========
# Recent 1000 games win rate :33.654%
#  -- 1000 Games WIN : 315 DRAW : 64 LOSS : 621
# Total win rate : 35.267%
#  -- TOTAL Games WIN : 15916 DRAW : 2870 LOSS : 29214
# ========== Training : Episode  49000  ===========
# Recent 1000 games win rate :35.881%
#  -- 1000 Games WIN : 338 DRAW : 58 LOSS : 604
# Total win rate : 35.280%
#  -- TOTAL Games WIN : 16254 DRAW : 2928 LOSS : 29818
# ========== Training : Episode  50000  ===========
# Recent 1000 games win rate :36.876%
#  -- 1000 Games WIN : 347 DRAW : 59 LOSS : 594
# Total win rate : 35.312%
#  -- TOTAL Games WIN : 16601 DRAW : 2987 LOSS : 30412
# ========== Training : Episode  51000  ===========
# Recent 1000 games win rate :35.494%
#  -- 1000 Games WIN : 334 DRAW : 59 LOSS : 607
# Total win rate : 35.315%
#  -- TOTAL Games WIN : 16935 DRAW : 3046 LOSS : 31019
# ========== Training : Episode  52000  ===========
# Recent 1000 games win rate :33.717%
#  -- 1000 Games WIN : 322 DRAW : 45 LOSS : 633
# Total win rate : 35.284%
#  -- TOTAL Games WIN : 17257 DRAW : 3091 LOSS : 31652
# ========== Training : Episode  53000  ===========
# Recent 1000 games win rate :35.775%
#  -- 1000 Games WIN : 337 DRAW : 58 LOSS : 605
# Total win rate : 35.293%
#  -- TOTAL Games WIN : 17594 DRAW : 3149 LOSS : 32257
# ========== Training : Episode  54000  ===========
# Recent 1000 games win rate :34.709%
#  -- 1000 Games WIN : 328 DRAW : 55 LOSS : 617
# Total win rate : 35.282%
#  -- TOTAL Games WIN : 17922 DRAW : 3204 LOSS : 32874
# ========== Training : Episode  55000  ===========
# Recent 1000 games win rate :36.190%
#  -- 1000 Games WIN : 342 DRAW : 55 LOSS : 603
# Total win rate : 35.299%
#  -- TOTAL Games WIN : 18264 DRAW : 3259 LOSS : 33477
# ========== Training : Episode  56000  ===========
# Recent 1000 games win rate :37.660%
#  -- 1000 Games WIN : 354 DRAW : 60 LOSS : 586
# Total win rate : 35.341%
#  -- TOTAL Games WIN : 18618 DRAW : 3319 LOSS : 34063
# ========== Training : Episode  57000  ===========
# Recent 1000 games win rate :35.966%
#  -- 1000 Games WIN : 337 DRAW : 63 LOSS : 600
# Total win rate : 35.352%
#  -- TOTAL Games WIN : 18955 DRAW : 3382 LOSS : 34663
# ========== Training : Episode  58000  ===========
# Recent 1000 games win rate :35.767%
#  -- 1000 Games WIN : 338 DRAW : 55 LOSS : 607
# Total win rate : 35.359%
#  -- TOTAL Games WIN : 19293 DRAW : 3437 LOSS : 35270
# ========== Training : Episode  59000  ===========
# Recent 1000 games win rate :35.095%
#  -- 1000 Games WIN : 332 DRAW : 54 LOSS : 614
# Total win rate : 35.355%
#  -- TOTAL Games WIN : 19625 DRAW : 3491 LOSS : 35884
# ========== Training : Episode  60000  ===========
# Recent 1000 games win rate :36.688%
#  -- 1000 Games WIN : 350 DRAW : 46 LOSS : 604
# Total win rate : 35.377%
#  -- TOTAL Games WIN : 19975 DRAW : 3537 LOSS : 36488
# ========== Training : Episode  61000  ===========
# Recent 1000 games win rate :35.225%
#  -- 1000 Games WIN : 329 DRAW : 66 LOSS : 605
# Total win rate : 35.375%
#  -- TOTAL Games WIN : 20304 DRAW : 3603 LOSS : 37093
# ========== Training : Episode  62000  ===========
# Recent 1000 games win rate :36.432%
#  -- 1000 Games WIN : 337 DRAW : 75 LOSS : 588
# Total win rate : 35.391%
#  -- TOTAL Games WIN : 20641 DRAW : 3678 LOSS : 37681
# ========== Training : Episode  63000  ===========
# Recent 1000 games win rate :37.342%
#  -- 1000 Games WIN : 354 DRAW : 52 LOSS : 594
# Total win rate : 35.423%
#  -- TOTAL Games WIN : 20995 DRAW : 3730 LOSS : 38275
# ========== Training : Episode  64000  ===========
# Recent 1000 games win rate :34.722%
#  -- 1000 Games WIN : 325 DRAW : 64 LOSS : 611
# Total win rate : 35.412%
#  -- TOTAL Games WIN : 21320 DRAW : 3794 LOSS : 38886
# ========== Training : Episode  65000  ===========
# Recent 1000 games win rate :37.754%
#  -- 1000 Games WIN : 353 DRAW : 65 LOSS : 582
# Total win rate : 35.448%
#  -- TOTAL Games WIN : 21673 DRAW : 3859 LOSS : 39468
# ========== Training : Episode  66000  ===========
# Recent 1000 games win rate :34.461%
#  -- 1000 Games WIN : 326 DRAW : 54 LOSS : 620
# Total win rate : 35.433%
#  -- TOTAL Games WIN : 21999 DRAW : 3913 LOSS : 40088
# ========== Training : Episode  67000  ===========
# Recent 1000 games win rate :39.562%
#  -- 1000 Games WIN : 379 DRAW : 42 LOSS : 579
# Total win rate : 35.495%
#  -- TOTAL Games WIN : 22378 DRAW : 3955 LOSS : 40667
# ========== Training : Episode  68000  ===========
# Recent 1000 games win rate :34.863%
#  -- 1000 Games WIN : 319 DRAW : 85 LOSS : 596
# Total win rate : 35.486%
#  -- TOTAL Games WIN : 22697 DRAW : 4040 LOSS : 41263
# ========== Training : Episode  69000  ===========
# Recent 1000 games win rate :34.783%
#  -- 1000 Games WIN : 328 DRAW : 57 LOSS : 615
# Total win rate : 35.476%
#  -- TOTAL Games WIN : 23025 DRAW : 4097 LOSS : 41878
# ========== Training : Episode  70000  ===========
# Recent 1000 games win rate :37.257%
#  -- 1000 Games WIN : 345 DRAW : 74 LOSS : 581
# Total win rate : 35.501%
#  -- TOTAL Games WIN : 23370 DRAW : 4171 LOSS : 42459
# ========== Training : Episode  71000  ===========
# Recent 1000 games win rate :33.511%
#  -- 1000 Games WIN : 315 DRAW : 60 LOSS : 625
# Total win rate : 35.473%
#  -- TOTAL Games WIN : 23685 DRAW : 4231 LOSS : 43084
# ========== Training : Episode  72000  ===========
# Recent 1000 games win rate :39.706%
#  -- 1000 Games WIN : 378 DRAW : 48 LOSS : 574
# Total win rate : 35.533%
#  -- TOTAL Games WIN : 24063 DRAW : 4279 LOSS : 43658
# ========== Training : Episode  73000  ===========
# Recent 1000 games win rate :34.829%
#  -- 1000 Games WIN : 326 DRAW : 64 LOSS : 610
# Total win rate : 35.523%
#  -- TOTAL Games WIN : 24389 DRAW : 4343 LOSS : 44268
# ========== Training : Episode  74000  ===========
# Recent 1000 games win rate :34.847%
#  -- 1000 Games WIN : 330 DRAW : 53 LOSS : 617
# Total win rate : 35.514%
#  -- TOTAL Games WIN : 24719 DRAW : 4396 LOSS : 44885
# ========== Training : Episode  75000  ===========
# Recent 1000 games win rate :33.156%
#  -- 1000 Games WIN : 311 DRAW : 62 LOSS : 627
# Total win rate : 35.482%
#  -- TOTAL Games WIN : 25030 DRAW : 4458 LOSS : 45512
# ========== Training : Episode  76000  ===========
# Recent 1000 games win rate :35.016%
#  -- 1000 Games WIN : 326 DRAW : 69 LOSS : 605
# Total win rate : 35.476%
#  -- TOTAL Games WIN : 25356 DRAW : 4527 LOSS : 46117
# ========== Training : Episode  77000  ===========
# Recent 1000 games win rate :37.527%
#  -- 1000 Games WIN : 349 DRAW : 70 LOSS : 581
# Total win rate : 35.503%
#  -- TOTAL Games WIN : 25705 DRAW : 4597 LOSS : 46698
# ========== Training : Episode  78000  ===========
# Recent 1000 games win rate :33.087%
#  -- 1000 Games WIN : 314 DRAW : 51 LOSS : 635
# Total win rate : 35.471%
#  -- TOTAL Games WIN : 26019 DRAW : 4648 LOSS : 47333
# ========== Training : Episode  79000  ===========
# Recent 1000 games win rate :36.305%
#  -- 1000 Games WIN : 338 DRAW : 69 LOSS : 593
# Total win rate : 35.482%
#  -- TOTAL Games WIN : 26357 DRAW : 4717 LOSS : 47926
# ========== Training : Episode  80000  ===========
# Recent 1000 games win rate :36.915%
#  -- 1000 Games WIN : 347 DRAW : 60 LOSS : 593
# Total win rate : 35.500%
#  -- TOTAL Games WIN : 26704 DRAW : 4777 LOSS : 48519
# ========== Training : Episode  81000  ===========
# Recent 1000 games win rate :33.228%
#  -- 1000 Games WIN : 316 DRAW : 49 LOSS : 635
# Total win rate : 35.471%
#  -- TOTAL Games WIN : 27020 DRAW : 4826 LOSS : 49154
# ========== Training : Episode  82000  ===========
# Recent 1000 games win rate :34.979%
#  -- 1000 Games WIN : 326 DRAW : 68 LOSS : 606
# Total win rate : 35.465%
#  -- TOTAL Games WIN : 27346 DRAW : 4894 LOSS : 49760
# ========== Training : Episode  83000  ===========
# Recent 1000 games win rate :35.944%
#  -- 1000 Games WIN : 335 DRAW : 68 LOSS : 597
# Total win rate : 35.471%
#  -- TOTAL Games WIN : 27681 DRAW : 4962 LOSS : 50357
# ========== Training : Episode  84000  ===========
# Recent 1000 games win rate :33.827%
#  -- 1000 Games WIN : 320 DRAW : 54 LOSS : 626
# Total win rate : 35.451%
#  -- TOTAL Games WIN : 28001 DRAW : 5016 LOSS : 50983
# ========== Training : Episode  85000  ===========
# Recent 1000 games win rate :34.464%
#  -- 1000 Games WIN : 325 DRAW : 57 LOSS : 618
# Total win rate : 35.440%
#  -- TOTAL Games WIN : 28326 DRAW : 5073 LOSS : 51601
# ========== Training : Episode  86000  ===========
# Recent 1000 games win rate :34.074%
#  -- 1000 Games WIN : 322 DRAW : 55 LOSS : 623
# Total win rate : 35.424%
#  -- TOTAL Games WIN : 28648 DRAW : 5128 LOSS : 52224
# ========== Training : Episode  87000  ===========
# Recent 1000 games win rate :32.595%
#  -- 1000 Games WIN : 309 DRAW : 52 LOSS : 639
# Total win rate : 35.391%
#  -- TOTAL Games WIN : 28957 DRAW : 5180 LOSS : 52863
# ========== Training : Episode  88000  ===========
# Recent 1000 games win rate :34.439%
#  -- 1000 Games WIN : 322 DRAW : 65 LOSS : 613
# Total win rate : 35.380%
#  -- TOTAL Games WIN : 29279 DRAW : 5245 LOSS : 53476
# ========== Training : Episode  89000  ===========
# Recent 1000 games win rate :32.692%
#  -- 1000 Games WIN : 306 DRAW : 64 LOSS : 630
# Total win rate : 35.350%
#  -- TOTAL Games WIN : 29585 DRAW : 5309 LOSS : 54106
# ========== Training : Episode  90000  ===========
# Recent 1000 games win rate :34.764%
#  -- 1000 Games WIN : 332 DRAW : 45 LOSS : 623
# Total win rate : 35.344%
#  -- TOTAL Games WIN : 29917 DRAW : 5354 LOSS : 54729
# ========== Training : Episode  91000  ===========
# Recent 1000 games win rate :37.846%
#  -- 1000 Games WIN : 355 DRAW : 62 LOSS : 583
# Total win rate : 35.371%
#  -- TOTAL Games WIN : 30272 DRAW : 5416 LOSS : 55312
# ========== Training : Episode  92000  ===========
# Recent 1000 games win rate :35.941%
#  -- 1000 Games WIN : 340 DRAW : 54 LOSS : 606
# Total win rate : 35.377%
#  -- TOTAL Games WIN : 30612 DRAW : 5470 LOSS : 55918
# ========== Training : Episode  93000  ===========
# Recent 1000 games win rate :39.958%
#  -- 1000 Games WIN : 378 DRAW : 54 LOSS : 568
# Total win rate : 35.427%
#  -- TOTAL Games WIN : 30990 DRAW : 5524 LOSS : 56486
# ========== Training : Episode  94000  ===========
# Recent 1000 games win rate :37.906%
#  -- 1000 Games WIN : 362 DRAW : 45 LOSS : 593
# Total win rate : 35.454%
#  -- TOTAL Games WIN : 31352 DRAW : 5569 LOSS : 57079
# ========== Training : Episode  95000  ===========
# Recent 1000 games win rate :33.654%
#  -- 1000 Games WIN : 315 DRAW : 64 LOSS : 621
# Total win rate : 35.435%
#  -- TOTAL Games WIN : 31667 DRAW : 5633 LOSS : 57700
# ========== Training : Episode  96000  ===========
# Recent 1000 games win rate :35.288%
#  -- 1000 Games WIN : 331 DRAW : 62 LOSS : 607
# Total win rate : 35.433%
#  -- TOTAL Games WIN : 31998 DRAW : 5695 LOSS : 58307
# ========== Training : Episode  97000  ===========
# Recent 1000 games win rate :34.388%
#  -- 1000 Games WIN : 326 DRAW : 52 LOSS : 622
# Total win rate : 35.422%
#  -- TOTAL Games WIN : 32324 DRAW : 5747 LOSS : 58929
# ========== Training : Episode  98000  ===========
# Recent 1000 games win rate :35.895%
#  -- 1000 Games WIN : 341 DRAW : 50 LOSS : 609
# Total win rate : 35.427%
#  -- TOTAL Games WIN : 32665 DRAW : 5797 LOSS : 59538
# ========== Training : Episode  99000  ===========
# Recent 1000 games win rate :36.105%
#  -- 1000 Games WIN : 343 DRAW : 50 LOSS : 607
# Total win rate : 35.434%
#  -- TOTAL Games WIN : 33008 DRAW : 5847 LOSS : 60145
# ========== Training : Episode  100000  ===========
# Recent 1000 games win rate :32.090%
#  -- 1000 Games WIN : 301 DRAW : 62 LOSS : 637
# Total win rate : 35.401%
#  -- TOTAL Games WIN : 33309 DRAW : 5909 LOSS : 60782
# ========== Training : Episode  101000  ===========
# Recent 1000 games win rate :37.869%
#  -- 1000 Games WIN : 359 DRAW : 52 LOSS : 589
# Total win rate : 35.425%
#  -- TOTAL Games WIN : 33668 DRAW : 5961 LOSS : 61371
# ========== Training : Episode  102000  ===========
# Recent 1000 games win rate :35.494%
#  -- 1000 Games WIN : 334 DRAW : 59 LOSS : 607
# Total win rate : 35.426%
#  -- TOTAL Games WIN : 34002 DRAW : 6020 LOSS : 61978
# ========== Training : Episode  103000  ===========
# Recent 1000 games win rate :34.076%
#  -- 1000 Games WIN : 321 DRAW : 58 LOSS : 621
# Total win rate : 35.413%
#  -- TOTAL Games WIN : 34323 DRAW : 6078 LOSS : 62599
# ========== Training : Episode  104000  ===========
# Recent 1000 games win rate :36.881%
#  -- 1000 Games WIN : 350 DRAW : 51 LOSS : 599
# Total win rate : 35.427%
#  -- TOTAL Games WIN : 34673 DRAW : 6129 LOSS : 63198
# ========== Training : Episode  105000  ===========
# Recent 1000 games win rate :35.419%
#  -- 1000 Games WIN : 334 DRAW : 57 LOSS : 609
# Total win rate : 35.427%
#  -- TOTAL Games WIN : 35007 DRAW : 6186 LOSS : 63807
# ========== Training : Episode  106000  ===========
# Recent 1000 games win rate :35.662%
#  -- 1000 Games WIN : 342 DRAW : 41 LOSS : 617
# Total win rate : 35.429%
#  -- TOTAL Games WIN : 35349 DRAW : 6227 LOSS : 64424
# ========== Training : Episode  107000  ===========
# Recent 1000 games win rate :37.167%
#  -- 1000 Games WIN : 349 DRAW : 61 LOSS : 590
# Total win rate : 35.446%
#  -- TOTAL Games WIN : 35698 DRAW : 6288 LOSS : 65014
# ========== Training : Episode  108000  ===========
# Recent 1000 games win rate :33.617%
#  -- 1000 Games WIN : 316 DRAW : 60 LOSS : 624
# Total win rate : 35.429%
#  -- TOTAL Games WIN : 36014 DRAW : 6348 LOSS : 65638
# ========== Training : Episode  109000  ===========
# Recent 1000 games win rate :34.047%
#  -- 1000 Games WIN : 318 DRAW : 66 LOSS : 616
# Total win rate : 35.416%
#  -- TOTAL Games WIN : 36332 DRAW : 6414 LOSS : 66254
# ========== Training : Episode  110000  ===========
# Recent 1000 games win rate :35.381%
#  -- 1000 Games WIN : 334 DRAW : 56 LOSS : 610
# Total win rate : 35.416%
#  -- TOTAL Games WIN : 36666 DRAW : 6470 LOSS : 66864
# ========== Training : Episode  111000  ===========
# Recent 1000 games win rate :34.015%
#  -- 1000 Games WIN : 316 DRAW : 71 LOSS : 613
# Total win rate : 35.403%
#  -- TOTAL Games WIN : 36982 DRAW : 6541 LOSS : 67477
# ========== Training : Episode  112000  ===========
# Recent 1000 games win rate :35.032%
#  -- 1000 Games WIN : 330 DRAW : 58 LOSS : 612
# Total win rate : 35.400%
#  -- TOTAL Games WIN : 37312 DRAW : 6599 LOSS : 68089
# ========== Training : Episode  113000  ===========
# Recent 1000 games win rate :35.829%
#  -- 1000 Games WIN : 335 DRAW : 65 LOSS : 600
# Total win rate : 35.404%
#  -- TOTAL Games WIN : 37647 DRAW : 6664 LOSS : 68689
# ========== Training : Episode  114000  ===========
# Recent 1000 games win rate :35.357%
#  -- 1000 Games WIN : 332 DRAW : 61 LOSS : 607
# Total win rate : 35.403%
#  -- TOTAL Games WIN : 37979 DRAW : 6725 LOSS : 69296
# ========== Training : Episode  115000  ===========
# Recent 1000 games win rate :36.120%
#  -- 1000 Games WIN : 337 DRAW : 67 LOSS : 596
# Total win rate : 35.410%
#  -- TOTAL Games WIN : 38316 DRAW : 6792 LOSS : 69892
# ========== Training : Episode  116000  ===========
# Recent 1000 games win rate :33.970%
#  -- 1000 Games WIN : 320 DRAW : 58 LOSS : 622
# Total win rate : 35.397%
#  -- TOTAL Games WIN : 38636 DRAW : 6850 LOSS : 70514
# ========== Training : Episode  117000  ===========
# Recent 1000 games win rate :36.181%
#  -- 1000 Games WIN : 343 DRAW : 52 LOSS : 605
# Total win rate : 35.404%
#  -- TOTAL Games WIN : 38979 DRAW : 6902 LOSS : 71119
# ========== Training : Episode  118000  ===========
# Recent 1000 games win rate :37.861%
#  -- 1000 Games WIN : 354 DRAW : 65 LOSS : 581
# Total win rate : 35.425%
#  -- TOTAL Games WIN : 39333 DRAW : 6967 LOSS : 71700
# ========== Training : Episode  119000  ===========
# Recent 1000 games win rate :35.941%
#  -- 1000 Games WIN : 340 DRAW : 54 LOSS : 606
# Total win rate : 35.429%
#  -- TOTAL Games WIN : 39673 DRAW : 7021 LOSS : 72306
# ========== Training : Episode  120000  ===========
# Recent 1000 games win rate :37.887%
#  -- 1000 Games WIN : 355 DRAW : 63 LOSS : 582
# Total win rate : 35.449%
#  -- TOTAL Games WIN : 40028 DRAW : 7084 LOSS : 72888
# ========== Training : Episode  121000  ===========
# Recent 1000 games win rate :35.326%
#  -- 1000 Games WIN : 331 DRAW : 63 LOSS : 606
# Total win rate : 35.448%
#  -- TOTAL Games WIN : 40359 DRAW : 7147 LOSS : 73494
# ========== Training : Episode  122000  ===========
# Recent 1000 games win rate :34.884%
#  -- 1000 Games WIN : 330 DRAW : 54 LOSS : 616
# Total win rate : 35.444%
#  -- TOTAL Games WIN : 40689 DRAW : 7201 LOSS : 74110
# ========== Training : Episode  123000  ===========
# Recent 1000 games win rate :34.681%
#  -- 1000 Games WIN : 326 DRAW : 60 LOSS : 614
# Total win rate : 35.437%
#  -- TOTAL Games WIN : 41015 DRAW : 7261 LOSS : 74724
# ========== Training : Episode  124000  ===========
# Recent 1000 games win rate :39.259%
#  -- 1000 Games WIN : 371 DRAW : 55 LOSS : 574
# Total win rate : 35.468%
#  -- TOTAL Games WIN : 41386 DRAW : 7316 LOSS : 75298
# ========== Training : Episode  125000  ===========
# Recent 1000 games win rate :39.185%
#  -- 1000 Games WIN : 375 DRAW : 43 LOSS : 582
# Total win rate : 35.499%
#  -- TOTAL Games WIN : 41761 DRAW : 7359 LOSS : 75880
# ========== Training : Episode  126000  ===========
# Recent 1000 games win rate :33.085%
#  -- 1000 Games WIN : 311 DRAW : 60 LOSS : 629
# Total win rate : 35.480%
#  -- TOTAL Games WIN : 42072 DRAW : 7419 LOSS : 76509
# ========== Training : Episode  127000  ===========
# Recent 1000 games win rate :35.090%
#  -- 1000 Games WIN : 333 DRAW : 51 LOSS : 616
# Total win rate : 35.476%
#  -- TOTAL Games WIN : 42405 DRAW : 7470 LOSS : 77125
# ========== Training : Episode  128000  ===========
# Recent 1000 games win rate :36.220%
#  -- 1000 Games WIN : 343 DRAW : 53 LOSS : 604
# Total win rate : 35.482%
#  -- TOTAL Games WIN : 42748 DRAW : 7523 LOSS : 77729
# ========== Training : Episode  129000  ===========
# Recent 1000 games win rate :37.286%
#  -- 1000 Games WIN : 349 DRAW : 64 LOSS : 587
# Total win rate : 35.496%
#  -- TOTAL Games WIN : 43097 DRAW : 7587 LOSS : 78316
# ========== Training : Episode  130000  ===========
# Recent 1000 games win rate :37.100%
#  -- 1000 Games WIN : 348 DRAW : 62 LOSS : 590
# Total win rate : 35.508%
#  -- TOTAL Games WIN : 43445 DRAW : 7649 LOSS : 78906
# ========== Training : Episode  131000  ===========
# Recent 1000 games win rate :38.550%
#  -- 1000 Games WIN : 367 DRAW : 48 LOSS : 585
# Total win rate : 35.532%
#  -- TOTAL Games WIN : 43812 DRAW : 7697 LOSS : 79491
# ========== Training : Episode  132000  ===========
# Recent 1000 games win rate :34.947%
#  -- 1000 Games WIN : 332 DRAW : 50 LOSS : 618
# Total win rate : 35.528%
#  -- TOTAL Games WIN : 44144 DRAW : 7747 LOSS : 80109
# ========== Training : Episode  133000  ===========
# Recent 1000 games win rate :37.379%
#  -- 1000 Games WIN : 348 DRAW : 69 LOSS : 583
# Total win rate : 35.541%
#  -- TOTAL Games WIN : 44492 DRAW : 7816 LOSS : 80692
# ========== Training : Episode  134000  ===========
# Recent 1000 games win rate :34.857%
#  -- 1000 Games WIN : 328 DRAW : 59 LOSS : 613
# Total win rate : 35.536%
#  -- TOTAL Games WIN : 44820 DRAW : 7875 LOSS : 81305
# ========== Training : Episode  135000  ===========
# Recent 1000 games win rate :35.456%
#  -- 1000 Games WIN : 334 DRAW : 58 LOSS : 608
# Total win rate : 35.536%
#  -- TOTAL Games WIN : 45154 DRAW : 7933 LOSS : 81913
# ========== Training : Episode  136000  ===========
# Recent 1000 games win rate :35.282%
#  -- 1000 Games WIN : 332 DRAW : 59 LOSS : 609
# Total win rate : 35.534%
#  -- TOTAL Games WIN : 45486 DRAW : 7992 LOSS : 82522
# ========== Training : Episode  137000  ===========
# Recent 1000 games win rate :34.889%
#  -- 1000 Games WIN : 329 DRAW : 57 LOSS : 614
# Total win rate : 35.529%
#  -- TOTAL Games WIN : 45815 DRAW : 8049 LOSS : 83136
# ========== Training : Episode  138000  ===========
# Recent 1000 games win rate :36.190%
#  -- 1000 Games WIN : 342 DRAW : 55 LOSS : 603
# Total win rate : 35.534%
#  -- TOTAL Games WIN : 46157 DRAW : 8104 LOSS : 83739
# ========== Training : Episode  139000  ===========
# Recent 1000 games win rate :34.409%
#  -- 1000 Games WIN : 320 DRAW : 70 LOSS : 610
# Total win rate : 35.526%
#  -- TOTAL Games WIN : 46477 DRAW : 8174 LOSS : 84349
# ========== Training : Episode  140000  ===========
# Recent 1000 games win rate :37.037%
#  -- 1000 Games WIN : 350 DRAW : 55 LOSS : 595
# Total win rate : 35.537%
#  -- TOTAL Games WIN : 46827 DRAW : 8229 LOSS : 84944
# ========== Training : Episode  141000  ===========
# Recent 1000 games win rate :35.263%
#  -- 1000 Games WIN : 335 DRAW : 50 LOSS : 615
# Total win rate : 35.535%
#  -- TOTAL Games WIN : 47162 DRAW : 8279 LOSS : 85559
# ========== Training : Episode  142000  ===========
# Recent 1000 games win rate :34.829%
#  -- 1000 Games WIN : 326 DRAW : 64 LOSS : 610
# Total win rate : 35.530%
#  -- TOTAL Games WIN : 47488 DRAW : 8343 LOSS : 86169
# ========== Training : Episode  143000  ===========
# Recent 1000 games win rate :33.369%
#  -- 1000 Games WIN : 312 DRAW : 65 LOSS : 623
# Total win rate : 35.515%
#  -- TOTAL Games WIN : 47800 DRAW : 8408 LOSS : 86792
# ========== Training : Episode  144000  ===========
# Recent 1000 games win rate :36.354%
#  -- 1000 Games WIN : 341 DRAW : 62 LOSS : 597
# Total win rate : 35.521%
#  -- TOTAL Games WIN : 48141 DRAW : 8470 LOSS : 87389
# ========== Training : Episode  145000  ===========
# Recent 1000 games win rate :34.847%
#  -- 1000 Games WIN : 330 DRAW : 53 LOSS : 617
# Total win rate : 35.516%
#  -- TOTAL Games WIN : 48471 DRAW : 8523 LOSS : 88006
# ========== Training : Episode  146000  ===========
# Recent 1000 games win rate :35.991%
#  -- 1000 Games WIN : 334 DRAW : 72 LOSS : 594
# Total win rate : 35.519%
#  -- TOTAL Games WIN : 48805 DRAW : 8595 LOSS : 88600
# ========== Training : Episode  147000  ===========
# Recent 1000 games win rate :34.295%
#  -- 1000 Games WIN : 321 DRAW : 64 LOSS : 615
# Total win rate : 35.511%
#  -- TOTAL Games WIN : 49126 DRAW : 8659 LOSS : 89215
# ========== Training : Episode  148000  ===========
# Recent 1000 games win rate :36.578%
#  -- 1000 Games WIN : 342 DRAW : 65 LOSS : 593
# Total win rate : 35.518%
#  -- TOTAL Games WIN : 49468 DRAW : 8724 LOSS : 89808
# ========== Training : Episode  149000  ===========
# Recent 1000 games win rate :34.081%
#  -- 1000 Games WIN : 319 DRAW : 64 LOSS : 617
# Total win rate : 35.508%
#  -- TOTAL Games WIN : 49787 DRAW : 8788 LOSS : 90425
# ========== Training : Episode  150000  ===========
# Recent 1000 games win rate :35.244%
#  -- 1000 Games WIN : 332 DRAW : 58 LOSS : 610
# Total win rate : 35.507%
#  -- TOTAL Games WIN : 50119 DRAW : 8846 LOSS : 91035
# ========== Training : Episode  151000  ===========
# Recent 1000 games win rate :35.759%
#  -- 1000 Games WIN : 339 DRAW : 52 LOSS : 609
# Total win rate : 35.508%
#  -- TOTAL Games WIN : 50458 DRAW : 8898 LOSS : 91644
# ========== Training : Episode  152000  ===========
# Recent 1000 games win rate :37.232%
#  -- 1000 Games WIN : 347 DRAW : 68 LOSS : 585
# Total win rate : 35.520%
#  -- TOTAL Games WIN : 50805 DRAW : 8966 LOSS : 92229
# ========== Training : Episode  153000  ===========
# Recent 1000 games win rate :33.972%
#  -- 1000 Games WIN : 319 DRAW : 61 LOSS : 620
# Total win rate : 35.509%
#  -- TOTAL Games WIN : 51124 DRAW : 9027 LOSS : 92849
# ========== Training : Episode  154000  ===========
# Recent 1000 games win rate :37.446%
#  -- 1000 Games WIN : 349 DRAW : 68 LOSS : 583
# Total win rate : 35.522%
#  -- TOTAL Games WIN : 51473 DRAW : 9095 LOSS : 93432
# ========== Training : Episode  155000  ===========
# Recent 1000 games win rate :35.118%
#  -- 1000 Games WIN : 328 DRAW : 66 LOSS : 606
# Total win rate : 35.519%
#  -- TOTAL Games WIN : 51801 DRAW : 9161 LOSS : 94038
# ========== Training : Episode  156000  ===========
# Recent 1000 games win rate :37.938%
#  -- 1000 Games WIN : 357 DRAW : 59 LOSS : 584
# Total win rate : 35.535%
#  -- TOTAL Games WIN : 52158 DRAW : 9220 LOSS : 94622
# ========== Training : Episode  157000  ===========
# Recent 1000 games win rate :34.362%
#  -- 1000 Games WIN : 323 DRAW : 60 LOSS : 617
# Total win rate : 35.527%
#  -- TOTAL Games WIN : 52481 DRAW : 9280 LOSS : 95239
# ========== Training : Episode  158000  ===========
# Recent 1000 games win rate :36.491%
#  -- 1000 Games WIN : 339 DRAW : 71 LOSS : 590
# Total win rate : 35.533%
#  -- TOTAL Games WIN : 52820 DRAW : 9351 LOSS : 95829
# ========== Training : Episode  159000  ===========
# Recent 1000 games win rate :32.801%
#  -- 1000 Games WIN : 308 DRAW : 61 LOSS : 631
# Total win rate : 35.516%
#  -- TOTAL Games WIN : 53128 DRAW : 9412 LOSS : 96460
# ========== Training : Episode  160000  ===========
# Recent 1000 games win rate :33.616%
#  -- 1000 Games WIN : 317 DRAW : 57 LOSS : 626
# Total win rate : 35.504%
#  -- TOTAL Games WIN : 53445 DRAW : 9469 LOSS : 97086
# ========== Training : Episode  161000  ===========
# Recent 1000 games win rate :32.412%
#  -- 1000 Games WIN : 305 DRAW : 59 LOSS : 636
# Total win rate : 35.485%
#  -- TOTAL Games WIN : 53750 DRAW : 9528 LOSS : 97722
# ========== Training : Episode  162000  ===========
# Recent 1000 games win rate :35.207%
#  -- 1000 Games WIN : 332 DRAW : 57 LOSS : 611
# Total win rate : 35.483%
#  -- TOTAL Games WIN : 54082 DRAW : 9585 LOSS : 98333
# ========== Training : Episode  163000  ===========
# Recent 1000 games win rate :36.373%
#  -- 1000 Games WIN : 339 DRAW : 68 LOSS : 593
# Total win rate : 35.489%
#  -- TOTAL Games WIN : 54421 DRAW : 9653 LOSS : 98926
# ========== Training : Episode  164000  ===========
# Recent 1000 games win rate :35.016%
#  -- 1000 Games WIN : 333 DRAW : 49 LOSS : 618
# Total win rate : 35.486%
#  -- TOTAL Games WIN : 54754 DRAW : 9702 LOSS : 99544
# ========== Training : Episode  165000  ===========
# Recent 1000 games win rate :35.294%
#  -- 1000 Games WIN : 330 DRAW : 65 LOSS : 605
# Total win rate : 35.485%
#  -- TOTAL Games WIN : 55084 DRAW : 9767 LOSS : 100149
# ========== Training : Episode  166000  ===========
# Recent 1000 games win rate :34.648%
#  -- 1000 Games WIN : 325 DRAW : 62 LOSS : 613
# Total win rate : 35.480%
#  -- TOTAL Games WIN : 55409 DRAW : 9829 LOSS : 100762
# ========== Training : Episode  167000  ===========
# Recent 1000 games win rate :36.780%
#  -- 1000 Games WIN : 345 DRAW : 62 LOSS : 593
# Total win rate : 35.487%
#  -- TOTAL Games WIN : 55754 DRAW : 9891 LOSS : 101355
# ========== Training : Episode  168000  ===========
# Recent 1000 games win rate :32.907%
#  -- 1000 Games WIN : 309 DRAW : 61 LOSS : 630
# Total win rate : 35.472%
#  -- TOTAL Games WIN : 56063 DRAW : 9952 LOSS : 101985
# ========== Training : Episode  169000  ===========
# Recent 1000 games win rate :36.286%
#  -- 1000 Games WIN : 340 DRAW : 63 LOSS : 597
# Total win rate : 35.477%
#  -- TOTAL Games WIN : 56403 DRAW : 10015 LOSS : 102582
# ========== Training : Episode  170000  ===========
# Recent 1000 games win rate :35.237%
#  -- 1000 Games WIN : 327 DRAW : 72 LOSS : 601
# Total win rate : 35.476%
#  -- TOTAL Games WIN : 56730 DRAW : 10087 LOSS : 103183
# ========== Training : Episode  171000  ===========
# Recent 1000 games win rate :33.759%
#  -- 1000 Games WIN : 317 DRAW : 61 LOSS : 622
# Total win rate : 35.466%
#  -- TOTAL Games WIN : 57047 DRAW : 10148 LOSS : 103805
# ========== Training : Episode  172000  ===========
# Recent 1000 games win rate :38.835%
#  -- 1000 Games WIN : 360 DRAW : 73 LOSS : 567
# Total win rate : 35.485%
#  -- TOTAL Games WIN : 57407 DRAW : 10221 LOSS : 104372
# ========== Training : Episode  173000  ===========
# Recent 1000 games win rate :31.472%
#  -- 1000 Games WIN : 293 DRAW : 69 LOSS : 638
# Total win rate : 35.462%
#  -- TOTAL Games WIN : 57700 DRAW : 10290 LOSS : 105010
# ========== Training : Episode  174000  ===========
# Recent 1000 games win rate :36.179%
#  -- 1000 Games WIN : 339 DRAW : 63 LOSS : 598
# Total win rate : 35.466%
#  -- TOTAL Games WIN : 58039 DRAW : 10353 LOSS : 105608
# ========== Training : Episode  175000  ===========
# Recent 1000 games win rate :34.043%
#  -- 1000 Games WIN : 320 DRAW : 60 LOSS : 620
# Total win rate : 35.458%
#  -- TOTAL Games WIN : 58359 DRAW : 10413 LOSS : 106228
# ========== Training : Episode  176000  ===========
# Recent 1000 games win rate :35.775%
#  -- 1000 Games WIN : 337 DRAW : 58 LOSS : 605
# Total win rate : 35.460%
#  -- TOTAL Games WIN : 58696 DRAW : 10471 LOSS : 106833
# ========== Training : Episode  177000  ===========
# Recent 1000 games win rate :33.938%
#  -- 1000 Games WIN : 318 DRAW : 63 LOSS : 619
# Total win rate : 35.451%
#  -- TOTAL Games WIN : 59014 DRAW : 10534 LOSS : 107452
# ========== Training : Episode  178000  ===========
# Recent 1000 games win rate :37.740%
#  -- 1000 Games WIN : 354 DRAW : 62 LOSS : 584
# Total win rate : 35.464%
#  -- TOTAL Games WIN : 59368 DRAW : 10596 LOSS : 108036
# ========== Training : Episode  179000  ===========
# Recent 1000 games win rate :31.618%
#  -- 1000 Games WIN : 295 DRAW : 67 LOSS : 638
# Total win rate : 35.443%
#  -- TOTAL Games WIN : 59663 DRAW : 10663 LOSS : 108674
# ========== Training : Episode  180000  ===========
# Recent 1000 games win rate :35.326%
#  -- 1000 Games WIN : 331 DRAW : 63 LOSS : 606
# Total win rate : 35.442%
#  -- TOTAL Games WIN : 59994 DRAW : 10726 LOSS : 109280
# ========== Training : Episode  181000  ===========
# Recent 1000 games win rate :35.217%
#  -- 1000 Games WIN : 324 DRAW : 80 LOSS : 596
# Total win rate : 35.441%
#  -- TOTAL Games WIN : 60318 DRAW : 10806 LOSS : 109876
# ========== Training : Episode  182000  ===========
# Recent 1000 games win rate :37.131%
#  -- 1000 Games WIN : 352 DRAW : 52 LOSS : 596
# Total win rate : 35.450%
#  -- TOTAL Games WIN : 60670 DRAW : 10858 LOSS : 110472
# ========== Training : Episode  183000  ===========
# Recent 1000 games win rate :32.806%
#  -- 1000 Games WIN : 311 DRAW : 52 LOSS : 637
# Total win rate : 35.436%
#  -- TOTAL Games WIN : 60981 DRAW : 10910 LOSS : 111109
# ========== Training : Episode  184000  ===========
# Recent 1000 games win rate :33.510%
#  -- 1000 Games WIN : 316 DRAW : 57 LOSS : 627
# Total win rate : 35.425%
#  -- TOTAL Games WIN : 61297 DRAW : 10967 LOSS : 111736
# ========== Training : Episode  185000  ===========
# Recent 1000 games win rate :34.483%
#  -- 1000 Games WIN : 330 DRAW : 43 LOSS : 627
# Total win rate : 35.420%
#  -- TOTAL Games WIN : 61627 DRAW : 11010 LOSS : 112363
# ========== Training : Episode  186000  ===========
# Recent 1000 games win rate :36.238%
#  -- 1000 Games WIN : 341 DRAW : 59 LOSS : 600
# Total win rate : 35.424%
#  -- TOTAL Games WIN : 61968 DRAW : 11069 LOSS : 112963
# ========== Training : Episode  187000  ===========
# Recent 1000 games win rate :34.672%
#  -- 1000 Games WIN : 328 DRAW : 54 LOSS : 618
# Total win rate : 35.420%
#  -- TOTAL Games WIN : 62296 DRAW : 11123 LOSS : 113581
# ========== Training : Episode  188000  ===========
# Recent 1000 games win rate :36.170%
#  -- 1000 Games WIN : 340 DRAW : 60 LOSS : 600
# Total win rate : 35.424%
#  -- TOTAL Games WIN : 62636 DRAW : 11183 LOSS : 114181
# ========== Training : Episode  189000  ===========
# Recent 1000 games win rate :32.725%
#  -- 1000 Games WIN : 305 DRAW : 68 LOSS : 627
# Total win rate : 35.410%
#  -- TOTAL Games WIN : 62941 DRAW : 11251 LOSS : 114808
# ========== Training : Episode  190000  ===========
# Recent 1000 games win rate :35.873%
#  -- 1000 Games WIN : 339 DRAW : 55 LOSS : 606
# Total win rate : 35.412%
#  -- TOTAL Games WIN : 63280 DRAW : 11306 LOSS : 115414
# ========== Training : Episode  191000  ===========
# Recent 1000 games win rate :37.714%
#  -- 1000 Games WIN : 353 DRAW : 64 LOSS : 583
# Total win rate : 35.424%
#  -- TOTAL Games WIN : 63633 DRAW : 11370 LOSS : 115997
# ========== Training : Episode  192000  ===========
# Recent 1000 games win rate :33.972%
#  -- 1000 Games WIN : 319 DRAW : 61 LOSS : 620
# Total win rate : 35.417%
#  -- TOTAL Games WIN : 63952 DRAW : 11431 LOSS : 116617
# ========== Training : Episode  193000  ===========
# Recent 1000 games win rate :34.365%
#  -- 1000 Games WIN : 322 DRAW : 63 LOSS : 615
# Total win rate : 35.412%
#  -- TOTAL Games WIN : 64274 DRAW : 11494 LOSS : 117232
# ========== Training : Episode  194000  ===========
# Recent 1000 games win rate :36.013%
#  -- 1000 Games WIN : 336 DRAW : 67 LOSS : 597
# Total win rate : 35.415%
#  -- TOTAL Games WIN : 64610 DRAW : 11561 LOSS : 117829
# ========== Training : Episode  195000  ===========
# Recent 1000 games win rate :32.660%
#  -- 1000 Games WIN : 307 DRAW : 60 LOSS : 633
# Total win rate : 35.400%
#  -- TOTAL Games WIN : 64917 DRAW : 11621 LOSS : 118462
# ========== Training : Episode  196000  ===========
# Recent 1000 games win rate :36.567%
#  -- 1000 Games WIN : 343 DRAW : 62 LOSS : 595
# Total win rate : 35.406%
#  -- TOTAL Games WIN : 65260 DRAW : 11683 LOSS : 119057
# ========== Training : Episode  197000  ===========
# Recent 1000 games win rate :36.111%
#  -- 1000 Games WIN : 338 DRAW : 64 LOSS : 598
# Total win rate : 35.410%
#  -- TOTAL Games WIN : 65598 DRAW : 11747 LOSS : 119655
# ========== Training : Episode  198000  ===========
# Recent 1000 games win rate :34.342%
#  -- 1000 Games WIN : 329 DRAW : 42 LOSS : 629
# Total win rate : 35.404%
#  -- TOTAL Games WIN : 65927 DRAW : 11789 LOSS : 120284
# ========== Training : Episode  199000  ===========
# Recent 1000 games win rate :37.182%
#  -- 1000 Games WIN : 351 DRAW : 56 LOSS : 593
# Total win rate : 35.413%
#  -- TOTAL Games WIN : 66278 DRAW : 11845 LOSS : 120877
# ========== Training : Episode  200000  ===========
# Recent 1000 games win rate :34.490%
#  -- 1000 Games WIN : 328 DRAW : 49 LOSS : 623
# Total win rate : 35.409%
#  -- TOTAL Games WIN : 66606 DRAW : 11894 LOSS : 121500
# ========== Training : Episode  201000  ===========
# Recent 1000 games win rate :35.624%
#  -- 1000 Games WIN : 337 DRAW : 54 LOSS : 609
# Total win rate : 35.410%
#  -- TOTAL Games WIN : 66943 DRAW : 11948 LOSS : 122109
# ========== Training : Episode  202000  ===========
# Recent 1000 games win rate :35.752%
#  -- 1000 Games WIN : 335 DRAW : 63 LOSS : 602
# Total win rate : 35.412%
#  -- TOTAL Games WIN : 67278 DRAW : 12011 LOSS : 122711
# ========== Training : Episode  203000  ===========
# Recent 1000 games win rate :35.269%
#  -- 1000 Games WIN : 328 DRAW : 70 LOSS : 602
# Total win rate : 35.411%
#  -- TOTAL Games WIN : 67606 DRAW : 12081 LOSS : 123313
# ========== Training : Episode  204000  ===========
# Recent 1000 games win rate :35.005%
#  -- 1000 Games WIN : 328 DRAW : 63 LOSS : 609
# Total win rate : 35.409%
#  -- TOTAL Games WIN : 67934 DRAW : 12144 LOSS : 123922
# ========== Training : Episode  205000  ===========
# Recent 1000 games win rate :38.478%
#  -- 1000 Games WIN : 369 DRAW : 41 LOSS : 590
# Total win rate : 35.424%
#  -- TOTAL Games WIN : 68303 DRAW : 12185 LOSS : 124512
# ========== Training : Episode  206000  ===========
# Recent 1000 games win rate :36.510%
#  -- 1000 Games WIN : 341 DRAW : 66 LOSS : 593
# Total win rate : 35.429%
#  -- TOTAL Games WIN : 68644 DRAW : 12251 LOSS : 125105
# ========== Training : Episode  207000  ===========
# Recent 1000 games win rate :32.757%
#  -- 1000 Games WIN : 303 DRAW : 75 LOSS : 622
# Total win rate : 35.417%
#  -- TOTAL Games WIN : 68947 DRAW : 12326 LOSS : 125727
# ========== Training : Episode  208000  ===========
# Recent 1000 games win rate :36.170%
#  -- 1000 Games WIN : 340 DRAW : 60 LOSS : 600
# Total win rate : 35.420%
#  -- TOTAL Games WIN : 69287 DRAW : 12386 LOSS : 126327
# ========== Training : Episode  209000  ===========
# Recent 1000 games win rate :34.979%
#  -- 1000 Games WIN : 326 DRAW : 68 LOSS : 606
# Total win rate : 35.418%
#  -- TOTAL Games WIN : 69613 DRAW : 12454 LOSS : 126933
# ========== Training : Episode  210000  ===========
# Recent 1000 games win rate :37.366%
#  -- 1000 Games WIN : 349 DRAW : 66 LOSS : 585
# Total win rate : 35.427%
#  -- TOTAL Games WIN : 69962 DRAW : 12520 LOSS : 127518
# ========== Training : Episode  211000  ===========
# Recent 1000 games win rate :34.074%
#  -- 1000 Games WIN : 322 DRAW : 55 LOSS : 623
# Total win rate : 35.421%
#  -- TOTAL Games WIN : 70284 DRAW : 12575 LOSS : 128141
# ========== Training : Episode  212000  ===========
# Recent 1000 games win rate :35.760%
#  -- 1000 Games WIN : 334 DRAW : 66 LOSS : 600
# Total win rate : 35.423%
#  -- TOTAL Games WIN : 70618 DRAW : 12641 LOSS : 128741
# ========== Training : Episode  213000  ===========
# Recent 1000 games win rate :34.567%
#  -- 1000 Games WIN : 327 DRAW : 54 LOSS : 619
# Total win rate : 35.418%
#  -- TOTAL Games WIN : 70945 DRAW : 12695 LOSS : 129360
# ========== Training : Episode  214000  ===========
# Recent 1000 games win rate :33.124%
#  -- 1000 Games WIN : 317 DRAW : 43 LOSS : 640
# Total win rate : 35.408%
#  -- TOTAL Games WIN : 71262 DRAW : 12738 LOSS : 130000
# ========== Training : Episode  215000  ===========
# Recent 1000 games win rate :37.263%
#  -- 1000 Games WIN : 354 DRAW : 50 LOSS : 596
# Total win rate : 35.416%
#  -- TOTAL Games WIN : 71616 DRAW : 12788 LOSS : 130596
# ========== Training : Episode  216000  ===========
# Recent 1000 games win rate :33.797%
#  -- 1000 Games WIN : 316 DRAW : 65 LOSS : 619
# Total win rate : 35.409%
#  -- TOTAL Games WIN : 71932 DRAW : 12853 LOSS : 131215
# ========== Training : Episode  217000  ===========
# Recent 1000 games win rate :34.086%
#  -- 1000 Games WIN : 317 DRAW : 70 LOSS : 613
# Total win rate : 35.403%
#  -- TOTAL Games WIN : 72249 DRAW : 12923 LOSS : 131828
# ========== Training : Episode  218000  ===========
# Recent 1000 games win rate :36.102%
#  -- 1000 Games WIN : 339 DRAW : 61 LOSS : 600
# Total win rate : 35.406%
#  -- TOTAL Games WIN : 72588 DRAW : 12984 LOSS : 132428
# ========== Training : Episode  219000  ===========
# Recent 1000 games win rate :36.209%
#  -- 1000 Games WIN : 340 DRAW : 61 LOSS : 599
# Total win rate : 35.410%
#  -- TOTAL Games WIN : 72928 DRAW : 13045 LOSS : 133027
# ========== Training : Episode  220000  ===========
# Recent 1000 games win rate :35.129%
#  -- 1000 Games WIN : 326 DRAW : 72 LOSS : 602
# Total win rate : 35.408%
#  -- TOTAL Games WIN : 73254 DRAW : 13117 LOSS : 133629
# ========== Training : Episode  221000  ===========
# Recent 1000 games win rate :36.421%
#  -- 1000 Games WIN : 346 DRAW : 50 LOSS : 604
# Total win rate : 35.413%
#  -- TOTAL Games WIN : 73600 DRAW : 13167 LOSS : 134233
# ========== Training : Episode  222000  ===========
# Recent 1000 games win rate :35.376%
#  -- 1000 Games WIN : 329 DRAW : 70 LOSS : 601
# Total win rate : 35.413%
#  -- TOTAL Games WIN : 73929 DRAW : 13237 LOSS : 134834
# ========== Training : Episode  223000  ===========
# Recent 1000 games win rate :36.528%
#  -- 1000 Games WIN : 343 DRAW : 61 LOSS : 596
# Total win rate : 35.418%
#  -- TOTAL Games WIN : 74272 DRAW : 13298 LOSS : 135430
# ========== Training : Episode  224000  ===========
# Recent 1000 games win rate :33.754%
#  -- 1000 Games WIN : 321 DRAW : 49 LOSS : 630
# Total win rate : 35.410%
#  -- TOTAL Games WIN : 74593 DRAW : 13347 LOSS : 136060
# ========== Training : Episode  225000  ===========
# Recent 1000 games win rate :38.943%
#  -- 1000 Games WIN : 361 DRAW : 73 LOSS : 566
# Total win rate : 35.426%
#  -- TOTAL Games WIN : 74954 DRAW : 13420 LOSS : 136626
# ========== Training : Episode  226000  ===========
# Recent 1000 games win rate :36.181%
#  -- 1000 Games WIN : 343 DRAW : 52 LOSS : 605
# Total win rate : 35.429%
#  -- TOTAL Games WIN : 75297 DRAW : 13472 LOSS : 137231
# ========== Training : Episode  227000  ===========
# Recent 1000 games win rate :38.298%
#  -- 1000 Games WIN : 360 DRAW : 60 LOSS : 580
# Total win rate : 35.442%
#  -- TOTAL Games WIN : 75657 DRAW : 13532 LOSS : 137811
# ========== Training : Episode  228000  ===========
# Recent 1000 games win rate :36.471%
#  -- 1000 Games WIN : 341 DRAW : 65 LOSS : 594
# Total win rate : 35.446%
# ...
# Recent 1000 games win rate :33.792%
#  -- 1000 Games WIN : 319 DRAW : 56 LOSS : 625
# Total win rate : 35.473%
#  -- TOTAL Games WIN : 308872 DRAW : 55267 LOSS : 561861
# ========== Training : Episode  927000  ===========
# Recent 1000 games win rate :35.432%
#  -- 1000 Games WIN : 332 DRAW : 63 LOSS : 605
# Total win rate : 35.473%
#  -- TOTAL Games WIN : 309204 DRAW : 55330 LOSS : 562466
# ========== Training : Episode  928000  ===========
# Recent 1000 games win rate :36.859%
#  -- 1000 Games WIN : 345 DRAW : 64 LOSS : 591
# Total win rate : 35.474%
#  -- TOTAL Games WIN : 309549 DRAW : 55394 LOSS : 563057
# ========== Training : Episode  929000  ===========
# Recent 1000 games win rate :35.368%
#  -- 1000 Games WIN : 336 DRAW : 50 LOSS : 614
# Total win rate : 35.474%
#  -- TOTAL Games WIN : 309885 DRAW : 55444 LOSS : 563671
# ========== Training : Episode  930000  ===========
# Recent 1000 games win rate :34.648%
#  -- 1000 Games WIN : 325 DRAW : 62 LOSS : 613
# Total win rate : 35.473%
#  -- TOTAL Games WIN : 310210 DRAW : 55506 LOSS : 564284
# ========== Training : Episode  931000  ===========
# Recent 1000 games win rate :36.538%
#  -- 1000 Games WIN : 342 DRAW : 64 LOSS : 594
# Total win rate : 35.474%
#  -- TOTAL Games WIN : 310552 DRAW : 55570 LOSS : 564878
# ========== Training : Episode  932000  ===========
# Recent 1000 games win rate :35.691%
#  -- 1000 Games WIN : 333 DRAW : 67 LOSS : 600
# Total win rate : 35.474%
#  -- TOTAL Games WIN : 310885 DRAW : 55637 LOSS : 565478
# ========== Training : Episode  933000  ===========
# Recent 1000 games win rate :32.770%
#  -- 1000 Games WIN : 310 DRAW : 54 LOSS : 636
# Total win rate : 35.472%
#  -- TOTAL Games WIN : 311195 DRAW : 55691 LOSS : 566114
# ========== Training : Episode  934000  ===========
# Recent 1000 games win rate :36.624%
#  -- 1000 Games WIN : 345 DRAW : 58 LOSS : 597
# Total win rate : 35.473%
#  -- TOTAL Games WIN : 311540 DRAW : 55749 LOSS : 566711
# ========== Training : Episode  935000  ===========
# Recent 1000 games win rate :34.047%
#  -- 1000 Games WIN : 318 DRAW : 66 LOSS : 616
# Total win rate : 35.471%
#  -- TOTAL Games WIN : 311858 DRAW : 55815 LOSS : 567327
# ========== Training : Episode  936000  ===========
# Recent 1000 games win rate :35.269%
#  -- 1000 Games WIN : 328 DRAW : 70 LOSS : 602
# Total win rate : 35.471%
#  -- TOTAL Games WIN : 312186 DRAW : 55885 LOSS : 567929
# ========== Training : Episode  937000  ===========
# Recent 1000 games win rate :36.431%
#  -- 1000 Games WIN : 345 DRAW : 53 LOSS : 602
# Total win rate : 35.472%
#  -- TOTAL Games WIN : 312531 DRAW : 55938 LOSS : 568531
# ========== Training : Episode  938000  ===========
# Recent 1000 games win rate :33.934%
#  -- 1000 Games WIN : 320 DRAW : 57 LOSS : 623
# Total win rate : 35.470%
#  -- TOTAL Games WIN : 312851 DRAW : 55995 LOSS : 569154
# ========== Training : Episode  939000  ===========
# Recent 1000 games win rate :34.792%
#  -- 1000 Games WIN : 334 DRAW : 40 LOSS : 626
# Total win rate : 35.470%
#  -- TOTAL Games WIN : 313185 DRAW : 56035 LOSS : 569780
# ========== Training : Episode  940000  ===========
# Recent 1000 games win rate :36.982%
#  -- 1000 Games WIN : 348 DRAW : 59 LOSS : 593
# Total win rate : 35.471%
#  -- TOTAL Games WIN : 313533 DRAW : 56094 LOSS : 570373
# ========== Training : Episode  941000  ===========
# Recent 1000 games win rate :34.261%
#  -- 1000 Games WIN : 320 DRAW : 66 LOSS : 614
# Total win rate : 35.470%
#  -- TOTAL Games WIN : 313853 DRAW : 56160 LOSS : 570987
# ========== Training : Episode  942000  ===========
# Recent 1000 games win rate :35.966%
#  -- 1000 Games WIN : 337 DRAW : 63 LOSS : 600
# Total win rate : 35.471%
#  -- TOTAL Games WIN : 314190 DRAW : 56223 LOSS : 571587
# ========== Training : Episode  943000  ===========
# Recent 1000 games win rate :37.646%
#  -- 1000 Games WIN : 355 DRAW : 57 LOSS : 588
# Total win rate : 35.473%
#  -- TOTAL Games WIN : 314545 DRAW : 56280 LOSS : 572175
# ========== Training : Episode  944000  ===========
# Recent 1000 games win rate :35.432%
#  -- 1000 Games WIN : 332 DRAW : 63 LOSS : 605
# Total win rate : 35.473%
#  -- TOTAL Games WIN : 314877 DRAW : 56343 LOSS : 572780
# ========== Training : Episode  945000  ===========
# Recent 1000 games win rate :37.380%
#  -- 1000 Games WIN : 351 DRAW : 61 LOSS : 588
# Total win rate : 35.475%
#  -- TOTAL Games WIN : 315228 DRAW : 56404 LOSS : 573368
# ========== Training : Episode  946000  ===========
# Recent 1000 games win rate :37.405%
#  -- 1000 Games WIN : 346 DRAW : 75 LOSS : 579
# Total win rate : 35.477%
#  -- TOTAL Games WIN : 315574 DRAW : 56479 LOSS : 573947
# ========== Training : Episode  947000  ===========
# Recent 1000 games win rate :35.426%
#  -- 1000 Games WIN : 333 DRAW : 60 LOSS : 607
# Total win rate : 35.477%
#  -- TOTAL Games WIN : 315907 DRAW : 56539 LOSS : 574554
# ========== Training : Episode  948000  ===========
# Recent 1000 games win rate :36.373%
#  -- 1000 Games WIN : 343 DRAW : 57 LOSS : 600
# Total win rate : 35.478%
#  -- TOTAL Games WIN : 316250 DRAW : 56596 LOSS : 575154
# ========== Training : Episode  949000  ===========
# Recent 1000 games win rate :32.808%
#  -- 1000 Games WIN : 312 DRAW : 49 LOSS : 639
# Total win rate : 35.475%
#  -- TOTAL Games WIN : 316562 DRAW : 56645 LOSS : 575793
# ========== Training : Episode  950000  ===========
# Recent 1000 games win rate :31.922%
#  -- 1000 Games WIN : 294 DRAW : 79 LOSS : 627
# Total win rate : 35.471%
#  -- TOTAL Games WIN : 316856 DRAW : 56724 LOSS : 576420
# ========== Training : Episode  951000  ===========
# Recent 1000 games win rate :36.510%
#  -- 1000 Games WIN : 341 DRAW : 66 LOSS : 593
# Total win rate : 35.472%
#  -- TOTAL Games WIN : 317197 DRAW : 56790 LOSS : 577013
# ========== Training : Episode  952000  ===========
# Recent 1000 games win rate :37.354%
#  -- 1000 Games WIN : 353 DRAW : 55 LOSS : 592
# Total win rate : 35.474%
#  -- TOTAL Games WIN : 317550 DRAW : 56845 LOSS : 577605
# ========== Training : Episode  953000  ===========
# Recent 1000 games win rate :34.916%
#  -- 1000 Games WIN : 331 DRAW : 52 LOSS : 617
# Total win rate : 35.474%
#  -- TOTAL Games WIN : 317881 DRAW : 56897 LOSS : 578222
# ========== Training : Episode  954000  ===========
# Recent 1000 games win rate :34.783%
#  -- 1000 Games WIN : 328 DRAW : 57 LOSS : 615
# Total win rate : 35.473%
#  -- TOTAL Games WIN : 318209 DRAW : 56954 LOSS : 578837
# ========== Training : Episode  955000  ===========
# Recent 1000 games win rate :34.842%
#  -- 1000 Games WIN : 331 DRAW : 50 LOSS : 619
# Total win rate : 35.472%
#  -- TOTAL Games WIN : 318540 DRAW : 57004 LOSS : 579456
# ========== Training : Episode  956000  ===========
# Recent 1000 games win rate :33.686%
#  -- 1000 Games WIN : 318 DRAW : 56 LOSS : 626
# Total win rate : 35.470%
#  -- TOTAL Games WIN : 318858 DRAW : 57060 LOSS : 580082
# ========== Training : Episode  957000  ===========
# Recent 1000 games win rate :35.263%
#  -- 1000 Games WIN : 335 DRAW : 50 LOSS : 615
# Total win rate : 35.470%
#  -- TOTAL Games WIN : 319193 DRAW : 57110 LOSS : 580697
# ========== Training : Episode  958000  ===========
# Recent 1000 games win rate :35.911%
#  -- 1000 Games WIN : 339 DRAW : 56 LOSS : 605
# Total win rate : 35.471%
#  -- TOTAL Games WIN : 319532 DRAW : 57166 LOSS : 581302
# ========== Training : Episode  959000  ===========
# Recent 1000 games win rate :36.903%
#  -- 1000 Games WIN : 348 DRAW : 57 LOSS : 595
# Total win rate : 35.472%
#  -- TOTAL Games WIN : 319880 DRAW : 57223 LOSS : 581897
# ========== Training : Episode  960000  ===========
# Recent 1000 games win rate :34.681%
#  -- 1000 Games WIN : 326 DRAW : 60 LOSS : 614
# Total win rate : 35.471%
#  -- TOTAL Games WIN : 320206 DRAW : 57283 LOSS : 582511
# ========== Training : Episode  961000  ===========
# Recent 1000 games win rate :34.402%
#  -- 1000 Games WIN : 322 DRAW : 64 LOSS : 614
# Total win rate : 35.470%
#  -- TOTAL Games WIN : 320528 DRAW : 57347 LOSS : 583125
# ========== Training : Episode  962000  ===========
# Recent 1000 games win rate :33.617%
#  -- 1000 Games WIN : 316 DRAW : 60 LOSS : 624
# Total win rate : 35.468%
#  -- TOTAL Games WIN : 320844 DRAW : 57407 LOSS : 583749
# ========== Training : Episode  963000  ===========
# Recent 1000 games win rate :35.737%
#  -- 1000 Games WIN : 337 DRAW : 57 LOSS : 606
# Total win rate : 35.469%
#  -- TOTAL Games WIN : 321181 DRAW : 57464 LOSS : 584355
# ========== Training : Episode  964000  ===========
# Recent 1000 games win rate :37.076%
#  -- 1000 Games WIN : 350 DRAW : 56 LOSS : 594
# Total win rate : 35.470%
#  -- TOTAL Games WIN : 321531 DRAW : 57520 LOSS : 584949
# ========== Training : Episode  965000  ===========
# Recent 1000 games win rate :37.354%
#  -- 1000 Games WIN : 353 DRAW : 55 LOSS : 592
# Total win rate : 35.472%
#  -- TOTAL Games WIN : 321884 DRAW : 57575 LOSS : 585541
# ========== Training : Episode  966000  ===========
# Recent 1000 games win rate :36.344%
#  -- 1000 Games WIN : 338 DRAW : 70 LOSS : 592
# Total win rate : 35.473%
#  -- TOTAL Games WIN : 322222 DRAW : 57645 LOSS : 586133
# ========== Training : Episode  967000  ===========
# Recent 1000 games win rate :33.369%
#  -- 1000 Games WIN : 310 DRAW : 71 LOSS : 619
# Total win rate : 35.471%
#  -- TOTAL Games WIN : 322532 DRAW : 57716 LOSS : 586752
# ========== Training : Episode  968000  ===========
# Recent 1000 games win rate :38.965%
#  -- 1000 Games WIN : 369 DRAW : 53 LOSS : 578
# Total win rate : 35.475%
#  -- TOTAL Games WIN : 322901 DRAW : 57769 LOSS : 587330
# ========== Training : Episode  969000  ===========
# Recent 1000 games win rate :35.412%
#  -- 1000 Games WIN : 335 DRAW : 54 LOSS : 611
# Total win rate : 35.475%
#  -- TOTAL Games WIN : 323236 DRAW : 57823 LOSS : 587941
# ========== Training : Episode  970000  ===========
# Recent 1000 games win rate :37.661%
#  -- 1000 Games WIN : 351 DRAW : 68 LOSS : 581
# Total win rate : 35.477%
#  -- TOTAL Games WIN : 323587 DRAW : 57891 LOSS : 588522
# ========== Training : Episode  971000  ===========
# Recent 1000 games win rate :36.441%
#  -- 1000 Games WIN : 344 DRAW : 56 LOSS : 600
# Total win rate : 35.478%
#  -- TOTAL Games WIN : 323931 DRAW : 57947 LOSS : 589122
# ========== Training : Episode  972000  ===========
# Recent 1000 games win rate :36.479%
#  -- 1000 Games WIN : 344 DRAW : 57 LOSS : 599
# Total win rate : 35.479%
#  -- TOTAL Games WIN : 324275 DRAW : 58004 LOSS : 589721
# ========== Training : Episode  973000  ===========
# Recent 1000 games win rate :34.252%
#  -- 1000 Games WIN : 323 DRAW : 57 LOSS : 620
# Total win rate : 35.478%
#  -- TOTAL Games WIN : 324598 DRAW : 58061 LOSS : 590341
# ========== Training : Episode  974000  ===========
# Recent 1000 games win rate :35.591%
#  -- 1000 Games WIN : 331 DRAW : 70 LOSS : 599
# Total win rate : 35.478%
#  -- TOTAL Games WIN : 324929 DRAW : 58131 LOSS : 590940
# ========== Training : Episode  975000  ===========
# Recent 1000 games win rate :36.258%
#  -- 1000 Games WIN : 343 DRAW : 54 LOSS : 603
# Total win rate : 35.478%
#  -- TOTAL Games WIN : 325272 DRAW : 58185 LOSS : 591543
# ========== Training : Episode  976000  ===========
# Recent 1000 games win rate :34.678%
#  -- 1000 Games WIN : 318 DRAW : 83 LOSS : 599
# Total win rate : 35.478%
#  -- TOTAL Games WIN : 325590 DRAW : 58268 LOSS : 592142
# ========== Training : Episode  977000  ===========
# Recent 1000 games win rate :39.071%
#  -- 1000 Games WIN : 370 DRAW : 53 LOSS : 577
# Total win rate : 35.481%
#  -- TOTAL Games WIN : 325960 DRAW : 58321 LOSS : 592719
# ========== Training : Episode  978000  ===========
# Recent 1000 games win rate :33.298%
#  -- 1000 Games WIN : 313 DRAW : 60 LOSS : 627
# Total win rate : 35.479%
#  -- TOTAL Games WIN : 326273 DRAW : 58381 LOSS : 593346
# ========== Training : Episode  979000  ===========
# Recent 1000 games win rate :38.511%
#  -- 1000 Games WIN : 362 DRAW : 60 LOSS : 578
# Total win rate : 35.482%
#  -- TOTAL Games WIN : 326635 DRAW : 58441 LOSS : 593924
# ========== Training : Episode  980000  ===========
# Recent 1000 games win rate :37.675%
#  -- 1000 Games WIN : 350 DRAW : 71 LOSS : 579
# Total win rate : 35.484%
#  -- TOTAL Games WIN : 326985 DRAW : 58512 LOSS : 594503
# ========== Training : Episode  981000  ===========
# Recent 1000 games win rate :34.152%
#  -- 1000 Games WIN : 320 DRAW : 63 LOSS : 617
# Total win rate : 35.483%
#  -- TOTAL Games WIN : 327305 DRAW : 58575 LOSS : 595120
# ========== Training : Episode  982000  ===========
# Recent 1000 games win rate :38.936%
#  -- 1000 Games WIN : 366 DRAW : 60 LOSS : 574
# Total win rate : 35.487%
#  -- TOTAL Games WIN : 327671 DRAW : 58635 LOSS : 595694
# ========== Training : Episode  983000  ===========
# Recent 1000 games win rate :36.047%
#  -- 1000 Games WIN : 341 DRAW : 54 LOSS : 605
# Total win rate : 35.487%
#  -- TOTAL Games WIN : 328012 DRAW : 58689 LOSS : 596299
# ========== Training : Episode  984000  ===========
# Recent 1000 games win rate :36.567%
#  -- 1000 Games WIN : 343 DRAW : 62 LOSS : 595
# Total win rate : 35.488%
#  -- TOTAL Games WIN : 328355 DRAW : 58751 LOSS : 596894
# ========== Training : Episode  985000  ===========
# Recent 1000 games win rate :39.664%
#  -- 1000 Games WIN : 378 DRAW : 47 LOSS : 575
# Total win rate : 35.493%
#  -- TOTAL Games WIN : 328733 DRAW : 58798 LOSS : 597469
# ========== Training : Episode  986000  ===========
# Recent 1000 games win rate :34.475%
#  -- 1000 Games WIN : 322 DRAW : 66 LOSS : 612
# Total win rate : 35.492%
#  -- TOTAL Games WIN : 329055 DRAW : 58864 LOSS : 598081
# ========== Training : Episode  987000  ===========
# Recent 1000 games win rate :36.864%
#  -- 1000 Games WIN : 348 DRAW : 56 LOSS : 596
# Total win rate : 35.493%
#  -- TOTAL Games WIN : 329403 DRAW : 58920 LOSS : 598677
# ========== Training : Episode  988000  ===========
# Recent 1000 games win rate :34.968%
#  -- 1000 Games WIN : 328 DRAW : 62 LOSS : 610
# Total win rate : 35.492%
#  -- TOTAL Games WIN : 329731 DRAW : 58982 LOSS : 599287
# ========== Training : Episode  989000  ===========
# Recent 1000 games win rate :37.527%
#  -- 1000 Games WIN : 352 DRAW : 62 LOSS : 586
# Total win rate : 35.494%
#  -- TOTAL Games WIN : 330083 DRAW : 59044 LOSS : 599873
# ========== Training : Episode  990000  ===========
# Recent 1000 games win rate :35.332%
#  -- 1000 Games WIN : 330 DRAW : 66 LOSS : 604
# Total win rate : 35.494%
#  -- TOTAL Games WIN : 330413 DRAW : 59110 LOSS : 600477
# ========== Training : Episode  991000  ===========
# Recent 1000 games win rate :38.380%
#  -- 1000 Games WIN : 360 DRAW : 62 LOSS : 578
# Total win rate : 35.497%
#  -- TOTAL Games WIN : 330773 DRAW : 59172 LOSS : 601055
# ========== Training : Episode  992000  ===========
# Recent 1000 games win rate :36.585%
#  -- 1000 Games WIN : 345 DRAW : 57 LOSS : 598
# Total win rate : 35.498%
#  -- TOTAL Games WIN : 331118 DRAW : 59229 LOSS : 601653
# ========== Training : Episode  993000  ===========
# Recent 1000 games win rate :34.196%
#  -- 1000 Games WIN : 317 DRAW : 73 LOSS : 610
# Total win rate : 35.497%
#  -- TOTAL Games WIN : 331435 DRAW : 59302 LOSS : 602263
# ========== Training : Episode  994000  ===========
# Recent 1000 games win rate :35.144%
#  -- 1000 Games WIN : 330 DRAW : 61 LOSS : 609
# Total win rate : 35.497%
#  -- TOTAL Games WIN : 331765 DRAW : 59363 LOSS : 602872
# ========== Training : Episode  995000  ===========
# Recent 1000 games win rate :36.706%
#  -- 1000 Games WIN : 341 DRAW : 71 LOSS : 588
# Total win rate : 35.498%
#  -- TOTAL Games WIN : 332106 DRAW : 59434 LOSS : 603460
# ========== Training : Episode  996000  ===========
# Recent 1000 games win rate :35.767%
#  -- 1000 Games WIN : 338 DRAW : 55 LOSS : 607
# Total win rate : 35.498%
#  -- TOTAL Games WIN : 332444 DRAW : 59489 LOSS : 604067
# ========== Training : Episode  997000  ===========
# Recent 1000 games win rate :33.015%
#  -- 1000 Games WIN : 311 DRAW : 58 LOSS : 631
# Total win rate : 35.496%
#  -- TOTAL Games WIN : 332755 DRAW : 59547 LOSS : 604698
# ========== Training : Episode  998000  ===========
# Recent 1000 games win rate :35.053%
#  -- 1000 Games WIN : 333 DRAW : 50 LOSS : 617
# Total win rate : 35.495%
#  -- TOTAL Games WIN : 333088 DRAW : 59597 LOSS : 605315
# ========== Training : Episode  999000  ===========
# Recent 1000 games win rate :36.481%
#  -- 1000 Games WIN : 340 DRAW : 68 LOSS : 592
# Total win rate : 35.496%
#  -- TOTAL Games WIN : 333428 DRAW : 59665 LOSS : 605907
# ========== Training : Episode  1000000  ===========
# Recent 1000 games win rate :34.677%
#  -- 1000 Games WIN : 327 DRAW : 57 LOSS : 616
# Total win rate : 35.495%
#  -- TOTAL Games WIN : 333755 DRAW : 59722 LOSS : 606523

# %% [markdown]
# ## 8. 학습 결과 시각화

# %%
print("Q-value with Usable Ace")
plot_q_val(agent, usable_ace=True)
print("Q-value without Usable Ace")
plot_q_val(agent, usable_ace=False)
print("Optimal policy with Usable Ace : (RED : STICK, BLUE : HIT)")
usable_result = plot_action(agent, usable_ace=True)
print("Optimal policy without Usable Ace : (RED : STICK, BLUE : HIT)")
no_usable_result = plot_action(agent, usable_ace=False)
# Out:
# Q-value with Usable Ace
# Q-value without Usable Ace
# Optimal policy with Usable Ace : (RED : STICK, BLUE : HIT)
# Optimal policy without Usable Ace : (RED : STICK, BLUE : HIT)

# %% [markdown]
# ----
# ## 9. 과제
#
# ### 목표
# 위 코드로부터 최적 Policy를 학습시킨 Agent를 사용하여, 블랙잭 게임을 시뮬레이션한 뒤 승률을 계산.
#
# ### 초기 설정
#  - 플레이어는 1,000,000번의 에피소드로부터 최적 Policy를 학습
#  - 플레이어의 초기 자금 : 10,000 달러
#  - 플레이어는 게임 참가 시 10 달러를 지불, 결과에 따라 금액을 획득
#      - 승리 시 : 20 달러 획득
#      - 무승부 시 : 10 달러 획득
#      - 패배 시 : 0 달러 획득
#
# ### 요구사항
#  - 플레이어와 딜러가 1,000번의 게임을 진행
#  - 1,000번의 게임 후 플레이어의 승률을 계산
#  - 매 게임 별 플레이어의 소지금 변화를 그래프로 시각화
#
# #### * HINT : MonteCarlo 클래스의 generate_episode(), train() 메소드를 참고할 것
# ----
# ### (과제 1) 1,000번의 게임 진행

# %%
agent_money = 10000
win_count = 0
lose_count = 0

money = []
count = []

for i in range(1000):
  agent_money -= 10
  deck.reset()
  agent.reset()
  dealer.reset()

  dealer.hit(deck)
  dealer.hit(deck)
  agent.hit(deck)
  agent.hit(deck)

  dealer_one = dealer.show()

  flag = False
  reward = 0

  while not flag:
    sums = agent.calculate_sum()
    if(sums < 12):
      agent.hit(deck)
      continue
    state = (sums,bool(agent.usable_ace),dealer_one)

    action = agent.policy(state)
    flag,reward = dealer.observation(action,agent,deck)

  dealer.action(deck)
  flag,reward = dealer.observation(action,agent,deck)
  

  if reward == 1 : 
    agent_money += 20
    win_count += 1

  elif reward == 0 :
    agent_money += 10

  elif reward == -1 :
    agent_money += 0
    lose_count += 1

  count.insert(i,i)
  money.insert(i,agent_money)

# %% [markdown]
# ### (과제 2) 플레이어의 승률을 계산

# %%
print(win_count/(win_count + lose_count))
# Out:
# 0.4901315789473684

# %% [markdown]
# ### (과제 3) 플레이어의 소지금 변화를 그래프로 시각화

# %%
plt.plot(count,money)
plt.xlabel('count')
plt.ylabel('money')

plt.title('Agent Money Plot')
plt.show()

# %% [markdown]
# ## 추가 과제 : 플레이어의 승률 높이기
# State를 수정하여 승률이 더 높은 policy를 찾기
#
# 기존 코드의 수정 필요
#  - 딜러는 게임이 끝났을 때, 남은 카드의 수를 확인
#  - 15장 이상이라면 해당 덱을 다음 게임에서 그대로 사용
#  - 15장 미만이라면 52장의 셔플된 새로운 카드를 기존 덱에 추가

# %%
############### 코드 작성 ##############################






########################################################

# %% [markdown]
# ---
# ### 참고자료
# [1] Reinforcement Learning - An Introduction (Richard S. Sutton, Andreow G. Barto), 2nd edition, p.120-124 https://web.stanford.edu/class/psych209/Readings/SuttonBartoIPRLBook2ndEd.pdf <br>
# [2] matplotlib.pyplot.plot Documentation, https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html <br>
# [3] matplotlib.pyplot.plot Examples https://matplotlib.org/tutorials/introductory/pyplot.html
