# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %% [markdown]
# ## 초기 파라미터 세팅 & EDA

# %%
import pandas as pd
import numpy as np
import os
import sys
import matplotlib.pyplot as plt
import seaborn as sns
import torch


CUR_PATH = './gdrive/My Drive/IGPS/software/kaggle/'
TRAIN_DATA_PATH = './gdrive/My Drive/IGPS/software/kaggle/data/train.csv'
TEST_DATA_PATH = './gdrive/My Drive/IGPS/software/kaggle/data/test.csv'

TRAIN_DATA = pd.read_csv(TRAIN_DATA_PATH) 
TEST_DATA = pd.read_csv(TEST_DATA_PATH)

#gpu 설정
device = 'cuda' if torch.cuda.is_available() else 'cpu'
torch.manual_seed(777)
if device == 'cuda':
    torch.cuda.manual_seed_all(777)

#hyper parameter
learning_rate = 0.001
training_epochs = 10
batch_size = 32

# %%
TRAIN_DATA.head(5)
print(np.shape(TRAIN_DATA))
# Out:
# (7352, 563)

# %%
plt.figure(figsize=(10,8))
plt.title('Barplot of Activity')
sns.countplot(TRAIN_DATA.Activity)
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3, 4, 5]), <a list of 6 Text major ticklabel objects>)

# %% [markdown]
# ## 데이터 전처리 & 데이터 로드

# %%
import numpy as np
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from config import config_info
from sklearn.preprocessing import StandardScaler

def load_data():
    
print("Hi~~")
